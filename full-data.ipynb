# %%
# !pip install tensorflow_addons medaiapipe--quiet
# Out:
# Requirement already satisfied: tensorflow_addons in /opt/conda/lib/python3.10/site-packages (0.20.0)
# ERROR: Could not find a version that satisfies the requirement medaiapipe--quiet (from versions: none)
# ERROR: No matching distribution found for medaiapipe--quiet

# %%
import os
import cv2
import csv
import math
import json
import scipy
import sklearn
import numpy as np
import pandas as pd
# import mediapipe as mp
import tensorflow as tf
import plotly.express as px
from tqdm.notebook import tqdm
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from collections import deque 
from sklearn.metrics import accuracy_score
from IPython.display import HTML
from tensorflow.keras import layers
import matplotlib.animation as animation
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split, GroupShuffleSplit
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# If True, processing data from scratch
# If False, loads preprocessed data
PREPROCESS_DATA = False
TRAIN_MODEL = True
USE_VAL = False
N_ROWS = 543
N_DIMS = 3
DIM_NAMES = ['x', 'y', 'z']
SEED = 42
NUM_CLASSES = 250
INPUT_SIZE = 64
BATCH_ALL_SIGNS_N = 3
BATCH_SIZE = 512
LR_MAX = 1e-3
# LR_MAX = 0.005 # #3
# LR_MAX = 0.00155 # #3
N_WARMUP_EPOCHS = 50
WD_RATIO = 0.05
MASK_VAL = 4237
N_EPOCHS = 100
VERBOSE = 1

# %%
NUM_CLASSES = 250
NUM_BLOCKS= 2
N_ROWS = 543
N_DIMS = 3

# final embedding and transformer embedding size
UNITS = 512 # WAS 512

# Transformer
MLP_RATIO = 4

# Dropout
EMBEDDING_DROPOUT = 0.00
MLP_DROPOUT_RATIO = 0.30 # WAS 0.40
CLASSIFIER_DROPOUT_RATIO = 0.10

# Initiailizers
INIT_HE_UNIFORM = tf.keras.initializers.he_uniform
INIT_GLOROT_UNIFORM = tf.keras.initializers.glorot_uniform
INIT_ZEROS = tf.keras.initializers.constant(0.0)
# Activations
GELU = tf.keras.activations.gelu
BATCH_ALL_SIGNS_N = 3

# %%
LIPS_UNITS = 384
HANDS_UNITS = 384
POSE_UNITS = 384
# final embedding and transformer embedding size
UNITS = 512
WD_RATIO = 0.05
INPUT_SIZE = 64
N_DIMS = 3

# %%
USE_TYPES = ['left_hand', 'pose', 'right_hand']
LHAND = np.arange(468, 489) # 21
RHAND = np.arange(522, 543) # 21
# POSE  = np.arange(489, 522)# 33
FACE  = np.arange(0,468) #468
LIP = np.array([ 0,
    61, 185, 40, 39, 37, 267, 269, 270, 409,
    291, 146, 91, 181, 84, 17, 314, 405, 321, 375,
    78, 191, 80, 81, 82, 13, 312, 311, 310, 415,
    95, 88, 178, 87, 14, 317, 402, 318, 324, 308,
])
LPOSE = np.array([502, 504, 506, 508, 510])
RPOSE = np.array([503, 505, 507, 509, 511])

# Concatenate the relevant landmarks for each dominant hand scenario
left_hand_dominant = np.concatenate((LIP, LHAND, LPOSE))
right_hand_dominant = np.concatenate((LIP, RHAND, RPOSE))
# landmarks = np.concatenate((LIP, RHAND, LHAND, POSE))
hand_index = np.concatenate((LHAND, RHAND), axis = 0)

#Landmark Indices in preprocess data
hands_index = np.argwhere(np.isin(left_hand_dominant, hand_index)).squeeze()
lip_index = np.argwhere(np.isin(left_hand_dominant, LIP)).squeeze()
left_hand_index = np.argwhere(np.isin(left_hand_dominant, LHAND)).squeeze()
right_hand_index = np.argwhere(np.isin(left_hand_dominant, RHAND)).squeeze()
pose_index = np.argwhere(np.isin(left_hand_dominant, LPOSE)).squeeze()
n_cols = left_hand_dominant.size

# %%
LIPS_START = 0
LEFT_HAND_START = lip_index.size
RIGHT_HAND_START = LEFT_HAND_START + left_hand_index.size
POSE_START = RIGHT_HAND_START + right_hand_index.size
print(f'LIPS_START: {LIPS_START}, LEFT_HAND_START: {LEFT_HAND_START}, RIGHT_HAND_START: {RIGHT_HAND_START}, POSE_START: {POSE_START}')
# Out:
# LIPS_START: 0, LEFT_HAND_START: 40, RIGHT_HAND_START: 61, POSE_START: 61

# %%
with open('/kaggle/input/asl-signs/sign_to_prediction_index_map.json') as f:
    sign_map = json.load(f)

signs = list(sign_map)

# %%
signs[:5]
# Out:
# ['TV', 'after', 'airplane', 'all', 'alligator']

# %%
BASE_DIR = '/kaggle/input/asl-signs'
train = pd.read_csv(f'{BASE_DIR}/train.csv')

# %%
def mapping_sign_code(sign: str):
    return sign_map[sign]
train['sign_code'] = train['sign'].apply(mapping_sign_code)

# %%
BASE_DIR_2 = '/kaggle/input/full-dataset'

# Load Train
X_train = np.load(f'{BASE_DIR_2}/X_train.npy')
y_train = np.load(f'{BASE_DIR_2}/y_train.npy')
NON_EMPTY_FRAME_IDXS_TRAIN = np.load(f'{BASE_DIR_2}/NON_EMPTY_FRAME_IDXS_TRAIN.npy')
# Load Test
X_test = np.load(f'{BASE_DIR_2}/X_test.npy')
y_test = np.load(f'{BASE_DIR_2}/y_test.npy')
NON_EMPTY_FRAME_IDXS_TEST = np.load(f'{BASE_DIR_2}/NON_EMPTY_FRAME_IDXS_TEST.npy')
# Load Val
X_val = np.load(f'{BASE_DIR_2}/X_val.npy')
y_val = np.load(f'{BASE_DIR_2}/y_val.npy')
NON_EMPTY_FRAME_IDXS_VAL = np.load(f'{BASE_DIR_2}/NON_EMPTY_FRAME_IDXS_VAL.npy')
# Define validation Data
validation_data = ({ 'frames': X_val, 'non_empty_frame_idxs': NON_EMPTY_FRAME_IDXS_VAL }, y_val)

# %%
lip_data = X_train[:, :, :40]
left_hand_data = X_train[:, :, 40:61]
pose_data = X_train[:, :, 61:66]

# %%
# Instantiate the encoder
le = LabelEncoder()

# Fit the encoder and transform the 'sign' column
train['sign_code'] = le.fit_transform(train['sign'])

# Create dictionaries for mapping
SIGN2ORD = dict(zip(le.classes_, le.transform(le.classes_)))
ORD2SIGN = dict(zip(le.transform(le.classes_), le.classes_))

# %%
LEFT_HANDS_MEAN_X = np.zeros([21], dtype=np.float32)
LEFT_HANDS_MEAN_Y = np.zeros([21], dtype=np.float32)
LEFT_HANDS_STD_X = np.zeros([21], dtype=np.float32)
LEFT_HANDS_STD_Y = np.zeros([21], dtype=np.float32)

for landmark_idx in range(21):
    for coord_idx in range(2):  # we consider only X and Y
        # we remove zero points
        coordinate_data = left_hand_data[:, :, landmark_idx, coord_idx]
        valid_points = coordinate_data[coordinate_data != 0]
        if coord_idx == 0:  # X
            LEFT_HANDS_MEAN_X[landmark_idx] = valid_points.mean()
            LEFT_HANDS_STD_X[landmark_idx] = valid_points.std()
        else:  # Y
            LEFT_HANDS_MEAN_Y[landmark_idx] = valid_points.mean()
            LEFT_HANDS_STD_Y[landmark_idx] = valid_points.std()

LEFT_HANDS_MEAN = np.array([LEFT_HANDS_MEAN_X, LEFT_HANDS_MEAN_Y]).T
LEFT_HANDS_STD = np.array([LEFT_HANDS_STD_X, LEFT_HANDS_STD_Y]).T

# %%
POSE_MEAN_X = np.zeros([5], dtype=np.float32)
POSE_MEAN_Y = np.zeros([5], dtype=np.float32)
POSE_STD_X = np.zeros([5], dtype=np.float32)
POSE_STD_Y = np.zeros([5], dtype=np.float32)

for landmark_idx in range(5):
    for coord_idx in range(2):  # we consider only X and Y
        # we remove zero points
        coordinate_data = pose_data[:, :, landmark_idx, coord_idx]
        valid_points = coordinate_data[coordinate_data != 0]
        if coord_idx == 0:  # X
            POSE_MEAN_X[landmark_idx] = valid_points.mean()
            POSE_STD_X[landmark_idx] = valid_points.std()
        else:  # Y
            POSE_MEAN_Y[landmark_idx] = valid_points.mean()
            POSE_STD_Y[landmark_idx] = valid_points.std()

POSE_MEAN = np.array([POSE_MEAN_X, POSE_MEAN_Y]).T
POSE_STD = np.array([POSE_STD_X, POSE_STD_Y]).T

# %%
LIP_MEAN_X = np.zeros([40], dtype=np.float32)
LIP_MEAN_Y = np.zeros([40], dtype=np.float32)
LIP_STD_X = np.zeros([40], dtype=np.float32)
LIP_STD_Y = np.zeros([40], dtype=np.float32)

for landmark_idx in range(40):
    for coord_idx in range(2):  # we consider only X and Y
        # we remove zero points
        coordinate_data = lip_data[:, :, landmark_idx, coord_idx]
        valid_points = coordinate_data[coordinate_data != 0]
        if coord_idx == 0:  # X
            LIP_MEAN_X[landmark_idx] = valid_points.mean()
            LIP_STD_X[landmark_idx] = valid_points.std()
        else:  # Y
            LIP_MEAN_Y[landmark_idx] = valid_points.mean()
            LIP_STD_Y[landmark_idx] = valid_points.std()

LIP_MEAN = np.array([LIP_MEAN_X, LIP_MEAN_Y]).T
LIP_STD = np.array([LIP_STD_X, LIP_STD_Y]).T

# %%
# Custom sampler to get a batch containing N times all signs
def get_train_batch_all_signs(X, y, NON_EMPTY_FRAME_IDXS, n=BATCH_ALL_SIGNS_N):
    # Arrays to store batch in
    X_batch = np.zeros([NUM_CLASSES*n, INPUT_SIZE, n_cols, N_DIMS], dtype=np.float32)
    y_batch = np.arange(0, NUM_CLASSES, step=1/n, dtype=np.float32).astype(np.int64)
    non_empty_frame_idxs_batch = np.zeros([NUM_CLASSES*n, INPUT_SIZE], dtype=np.float32)

    # Dictionary mapping ordinally encoded sign to corresponding sample indices
    CLASS2IDXS = {}
    for i in range(NUM_CLASSES):
        CLASS2IDXS[i] = np.argwhere(y == i).squeeze().astype(np.int32)

    while True:
        # Fill batch arrays
        for i in range(NUM_CLASSES):
            idxs = np.random.choice(CLASS2IDXS[i], n)
            X_batch[i*n:(i+1)*n] = X[idxs]
            non_empty_frame_idxs_batch[i*n:(i+1)*n] = NON_EMPTY_FRAME_IDXS[idxs]
        yield { 'frames': X_batch, 'non_empty_frame_idxs': non_empty_frame_idxs_batch }, y_batch

# %%
# The `LandmarkEmbedding` class is responsible for generating embeddings for a specific type of landmark.
class LandmarkEmbedding(tf.keras.Model):
    def __init__(self, units, name):
        super(LandmarkEmbedding, self).__init__(name=f'{name}_embedding')
        self.units = units

    def build(self, input_shape):
        # The 'empty_embedding' represents the case when a landmark is missing from a given frame. EMBEDDING FOR WHEN LANDMARK IS MISSING FROM A FRAME
        # It is initialized as a zero vector of size equal to `units`.
        self.empty_embedding = self.add_weight(
            name=f'{self.name}_empty_embedding',
            shape=[self.units],
            initializer=INIT_ZEROS,
        )
        '''
        A Dense Neural Network Layer is being used to map the input data to a point (or a vector) in the embedding space.
        Therefore similar or related input data are being mapped to points that are close together in the embedding space,
        while unrelated or dissimilar data will be mapped to points that are further apart.

        The coordinates of the landmarks are transformed from their original space (where they might just represent spatial
        coordinates) to an "embedding space" where the coordinates carry more semantic meaning that can help the model understand
        the gestures or signs being made.
        '''
        # Transforming the landmark data(Lips, Hands, Pose) into the embedding space by passing the data through two fully connected 'dense' layers with GELU activations.
        self.dense = tf.keras.Sequential([
            tf.keras.layers.Dense(self.units, name=f'{self.name}_dense_1', use_bias=False, kernel_initializer='glorot_uniform'),
            tf.keras.layers.Activation('gelu'),
            tf.keras.layers.Dense(self.units, name=f'{self.name}_dense_2', use_bias=False, kernel_initializer='he_uniform'),
        ], name=f'{self.name}_dense')

    def call(self, x):
        # If a landmark is missing from a frame (indicated by a zero sum of the landmark coordinates),
        # the 'empty_embedding' is returned. Otherwise, the dense layers are applied to generate the embedding.
        embedding_output = tf.where(
            tf.reduce_sum(x, axis=2, keepdims=True) == 0,
            self.empty_embedding,
            self.dense(x),
        )
        # Assertion
        tf.debugging.assert_shapes([
            (embedding_output, (None, 64, self.units))
        ])

        return embedding_output

# %%
# Generates the final embeddings for all landmarks and combines them.
class Embedding(tf.keras.Model):
    def __init__(self):
        super(Embedding, self).__init__()
        # self.input_size = input_size
        # self.units = units
    def get_diffs(self, l):
        S = l.shape[2]
        other = tf.expand_dims(l, 3)
        other = tf.repeat(other, S, axis=3)
        other = tf.transpose(other, [0,1,3,2])
        diffs = tf.expand_dims(l, 3) - other
        diffs = tf.reshape(diffs, [-1, INPUT_SIZE, S*S])
        return diffs

    def build(self, input_shape):
        # 'positional_embedding' initialized with zero
        self.positional_embedding = tf.keras.layers.Embedding(INPUT_SIZE+1, UNITS, embeddings_initializer=INIT_ZEROS)

        # Create the landmark-specific embedding layers
        self.lips_embedding = LandmarkEmbedding(LIPS_UNITS, 'lips')
        self.left_hand_embedding = LandmarkEmbedding(HANDS_UNITS, 'left_hand')
        self.pose_embedding = LandmarkEmbedding(POSE_UNITS, 'pose')

        # The weights for combining the landmark embeddings. Initialized to zeros, they will be learned during training.
        self.landmark_weights = tf.Variable(tf.zeros([3], dtype=tf.float32), name='landmark_weights')

        # A couple of dense layers to further process the combined embeddings
        self.fc = tf.keras.Sequential([
            tf.keras.layers.Dense(UNITS, name='fully_connected_1', use_bias=False, kernel_initializer='glorot_uniform'),
            tf.keras.layers.Activation('gelu'),
            tf.keras.layers.Dense(UNITS, name='fully_connected_2', use_bias=False, kernel_initializer='he_uniform'),
        ], name='fc')

    def call(self, lips0, left_hand0, pose0, non_empty_frame_idxs, training=False):
        # Embed the landmarks using the respective embedding layers
        lips_embedding = self.lips_embedding(lips0)
        left_hand_embedding = self.left_hand_embedding(left_hand0)
        pose_embedding = self.pose_embedding(pose0)


        # The embeddings are stacked together along a new dimension, and then weighted and summed to form a single vector.
        # The weights are normalized using a softmax function, which ensures that they sum to 1.
        x = tf.stack((lips_embedding, left_hand_embedding, pose_embedding), axis=3)
        x = x * tf.nn.softmax(self.landmark_weights)
        x = tf.reduce_sum(x, axis=3)


        # Pass the combined embedding through the two fully connected layers
        x = self.fc(x)
        # print(f'X Shape : {x.shape}')

        # Add the positional embedding
        max_frame_idxs = tf.clip_by_value(
                tf.reduce_max(non_empty_frame_idxs, axis=1, keepdims=True),
                1,
                np.PINF,
            )
        # print('Max Frame Index')
        normalised_non_empty_frame_idxs = tf.where(
            tf.math.equal(non_empty_frame_idxs, -1.0),
            INPUT_SIZE,
            tf.cast(
                non_empty_frame_idxs / max_frame_idxs * INPUT_SIZE,
                tf.int32,
            ),
        )
        x = x + self.positional_embedding(normalised_non_empty_frame_idxs)

        return x
# scaled dot-product and Multiheadattention Transformer
def scaled_dot_product(q,k,v, softmax, attention_mask):
    #calculates Q . K(transpose)
    qkt = tf.matmul(q,k,transpose_b=True)
    #caculates scaling factor
    dk = tf.math.sqrt(tf.cast(q.shape[-1],dtype=tf.float32))
    scaled_qkt = qkt/dk
    softmax = softmax(scaled_qkt, mask=attention_mask)

    z = tf.matmul(softmax,v)
    #shape: (m,Tx,depth), same shape as q,k,v
    return z

class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self,d_model,num_of_heads):
        super(MultiHeadAttention,self).__init__()
        self.d_model = d_model
        self.num_of_heads = num_of_heads
        self.depth = d_model//num_of_heads
        self.wq = [tf.keras.layers.Dense(self.depth) for i in range(num_of_heads)]
        self.wk = [tf.keras.layers.Dense(self.depth) for i in range(num_of_heads)]
        self.wv = [tf.keras.layers.Dense(self.depth) for i in range(num_of_heads)]
        self.wo = tf.keras.layers.Dense(d_model)
        self.softmax = tf.keras.layers.Softmax()

    def call(self,x, attention_mask):

        multi_attn = []
        for i in range(self.num_of_heads):
            Q = self.wq[i](x)
            K = self.wk[i](x)
            V = self.wv[i](x)
            multi_attn.append(scaled_dot_product(Q,K,V, self.softmax, attention_mask))

        multi_head = tf.concat(multi_attn,axis=-1)
        multi_head_attention = self.wo(multi_head)
        return multi_head_attention
# Full Transformer
class Transformer(tf.keras.Model):
    def __init__(self, num_blocks):
        super(Transformer, self).__init__(name='transformer')
        self.num_blocks = num_blocks

    def build(self, input_shape):
        self.ln_1s = []
        self.mhas = []
        self.ln_2s = []
        self.mlps = []
        # Make Transformer Blocks
        for i in range(self.num_blocks):
            # Multi Head Attention
            self.mhas.append(MultiHeadAttention(UNITS, 8))
            # Multi Layer Perception
            self.mlps.append(tf.keras.Sequential([
                tf.keras.layers.Dense(UNITS * MLP_RATIO, activation=GELU, kernel_initializer=INIT_GLOROT_UNIFORM),
                tf.keras.layers.Dropout(MLP_DROPOUT_RATIO),
                tf.keras.layers.Dense(UNITS, kernel_initializer=INIT_HE_UNIFORM),
            ]))

    def call(self, x, attention_mask):
        # Iterate input over transformer blocks
        for mha, mlp in zip(self.mhas, self.mlps):
            x = x + mha(x, attention_mask)
            x = x + mlp(x)

        return x
def scce_with_ls(y_true, y_pred):
    # One Hot Encode Sparsely Encoded Target Sign
    y_true = tf.cast(y_true, tf.int32)
    y_true = tf.one_hot(y_true, NUM_CLASSES, axis=1)
    y_true = tf.squeeze(y_true, axis=2)
    # Categorical Crossentropy with native label smoothing support
    return tf.keras.losses.categorical_crossentropy(y_true, y_pred, label_smoothing=0.25)
#Dimeji get_model
def get_transformer_model():
    # Inputs
    frames = tf.keras.layers.Input([INPUT_SIZE, n_cols, N_DIMS], dtype=tf.float32, name='frames')
    non_empty_frame_idxs = tf.keras.layers.Input([INPUT_SIZE], dtype=tf.float32, name='non_empty_frame_idxs')

    # Padding Mask
    mask0 = tf.cast(tf.math.not_equal(non_empty_frame_idxs, -1), tf.float32)
    mask0 = tf.expand_dims(mask0, axis=2)
    # Random Frame Masking
    mask = tf.where(
        (tf.random.uniform(tf.shape(mask0)) > 0.25) & tf.math.not_equal(mask0, 0.0),
        1.0,
        0.0,
    )
    # Correct Samples Which are all masked now...
    mask = tf.where(
        tf.math.equal(tf.reduce_sum(mask, axis=[1,2], keepdims=True), 0.0),
        mask0,
        mask,
    )

    x = tf.slice(frames, [0,0,0,0], [-1,INPUT_SIZE, n_cols, 2])

    # LIPS
    lips = tf.slice(x, [0,0,LIPS_START,0], [-1,INPUT_SIZE, 40, 2])
    lips = tf.where(
            tf.math.equal(lips, 0.0),
            0.0,
            (lips - LIP_MEAN) / LIP_STD,
        )

    # LEFT HAND
    left_hand = tf.slice(x, [0,0,40,0], [-1,INPUT_SIZE, 21, 2])
    left_hand = tf.where(
            tf.math.equal(left_hand, 0.0),
            0.0,
            (left_hand - LEFT_HANDS_MEAN) / LEFT_HANDS_STD,
        )

    # POSE
    pose = tf.slice(x, [0,0,61,0], [-1,INPUT_SIZE, 5, 2])
    pose = tf.where(
            tf.math.equal(pose, 0.0),
            0.0,
            (pose - POSE_MEAN) / POSE_STD,
        )

    # Flatten
    lips = tf.reshape(lips, [-1, INPUT_SIZE, 40*2])
    left_hand = tf.reshape(left_hand, [-1, INPUT_SIZE, 21*2])
    pose = tf.reshape(pose, [-1, INPUT_SIZE, 5*2])
    # Embedding
    x = Embedding()(lips, left_hand, pose, non_empty_frame_idxs)

    # Encoder Transformer Block
    x = Transformer(NUM_BLOCKS)(x, mask)

    # Pooling
    x = tf.reduce_sum(x * mask, axis=1) / tf.reduce_sum(mask, axis=1)

    # Classifier Dropout
    x = tf.keras.layers.Dropout(CLASSIFIER_DROPOUT_RATIO)(x)
    # Classification Layer
    x = tf.keras.layers.Dense(NUM_CLASSES, activation=tf.keras.activations.softmax, kernel_initializer=INIT_GLOROT_UNIFORM)(x)

    outputs = x

    # Create Tensorflow Model
    model = tf.keras.models.Model(inputs=[frames, non_empty_frame_idxs], outputs=outputs)

    # Sparse Categorical Cross Entropy With Label Smoothing
    loss = scce_with_ls
    optimizer = tfa.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-5, clipnorm=1.0)
    # TopK Metrics
    metrics = [
        tf.keras.metrics.SparseCategoricalAccuracy(name='acc'),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name='top_5_acc'),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=10, name='top_10_acc'),
    ]

    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
    return model
# tf.keras.backend.clear_session()
transformer_model = get_transformer_model()

# %%
# Custom callback to update weight decay with learning rate
class WeightDecayCallback(tf.keras.callbacks.Callback):
    def __init__(self, wd_ratio=WD_RATIO):
        self.step_counter = 0
        self.wd_ratio = wd_ratio

    def on_epoch_begin(self, epoch, logs=None):
        transformer_model.optimizer.weight_decay = transformer_model.optimizer.learning_rate * self.wd_ratio
        print(f'learning rate: {transformer_model.optimizer.learning_rate.numpy():.2e}, weight decay: {transformer_model.optimizer.weight_decay.numpy():.2e}')
def lrfn(current_step, num_warmup_steps, lr_max, num_cycles=0.5,num_training_steps=N_EPOCHS):
    if current_step < num_warmup_steps:
        return lr_max * 2 ** -(num_warmup_steps - current_step)
    else:
        progress = float(current_step - num_warmup_steps) / float(max(1, num_training_steps - num_warmup_steps))
        return max(0.0, 0.5 * (1.0 + math.cos(math.pi * float(num_cycles) * 2.0 * progress))) * lr_max

# Learning rate for encoder
LR_SCHEDULE = [lrfn(step, num_warmup_steps=N_WARMUP_EPOCHS, lr_max=LR_MAX, num_cycles=0.50) for step in range(N_EPOCHS)]
# Learning Rate Callback
lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda step: LR_SCHEDULE[step], verbose=1)

# %%
class SignificantIncreaseStopping(tf.keras.callbacks.Callback):
    def __init__(self, threshold=20.0, start_epoch=30, monitor_loss='val_loss', monitor_acc='val_acc', acc_check_epochs=3):
        super(SignificantIncreaseStopping, self).__init__()
        self.threshold = threshold
        self.start_epoch = start_epoch
        self.monitor_loss = monitor_loss
        self.monitor_acc = monitor_acc
        self.acc_check_epochs = acc_check_epochs
        self.last_accuracies = deque(maxlen=acc_check_epochs)
        self.best_weights = None
        self.best_acc = -np.inf

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}

        # Save the best weights if current accuracy is greater than the previous best
        current_acc = logs.get(self.monitor_acc)
        if current_acc is not None and current_acc > self.best_acc:
            self.best_acc = current_acc
            self.best_weights = self.model.get_weights()

        # Check for significant increase in loss after start_epoch
        if epoch >= self.start_epoch:
            current_loss = logs.get(self.monitor_loss)
            if current_loss - self.prev_loss > self.threshold:
                print(f"\nCumulative significant increase in `{self.monitor_loss}` detected. Stopping training.")
                if self.best_weights:
                    self.model.set_weights(self.best_weights)
                self.model.stop_training = True

        self.prev_loss = logs.get(self.monitor_loss)

        # Check for constant accuracy
        self.last_accuracies.append(logs.get(self.monitor_acc))
        if len(self.last_accuracies) == self.acc_check_epochs:
          if len(set(self.last_accuracies)) == 1 and current_acc > 0.9: # Check if all accuracies are the same and the current accuracy is > 0.9
            print(f"\nAccuracy has been constant for the last {self.acc_check_epochs} epochs and is greater than 0.9. Stopping training.")
            if self.best_weights:
                self.model.set_weights(self.best_weights)
            self.model.stop_training = True

        # if len(self.last_accuracies) == self.acc_check_epochs and len(set(self.last_accuracies)) == 1 and current_acc > 0.9:

    def on_train_begin(self, logs=None):
        self.prev_loss = np.inf

increase_stopping = SignificantIncreaseStopping(threshold=20.0, start_epoch=30, monitor_loss='val_loss', monitor_acc='val_acc', acc_check_epochs=3)

# %%
# from tensorflow.keras.callbacks import EarlyStopping

# Clear all models in GPU
tf.keras.backend.clear_session()

# Get new fresh model
model = transformer_model


# Define the EarlyStopping callback
# early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)


# Sanity Check
model.summary()

# Actual Training
transformer_history = model.fit(
        x=get_train_batch_all_signs(X_train, y_train, NON_EMPTY_FRAME_IDXS_TRAIN),
        steps_per_epoch=len(X_train) // (NUM_CLASSES * BATCH_ALL_SIGNS_N),
        epochs=N_EPOCHS,
        # Only used for validation data since training data is a generator
        batch_size=BATCH_SIZE,
        validation_data=validation_data,
        callbacks=[
            lr_callback,
            WeightDecayCallback(),
            increase_stopping,
        ],
        verbose = VERBOSE,
)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  non_empty_frame_idxs (InputLay  [(None, 64)]        0           []
#  er)
#
#  tf.math.not_equal (TFOpLambda)  (None, 64)          0           ['non_empty_frame_idxs[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 64)           0           ['tf.math.not_equal[0][0]']
#
#  tf.expand_dims (TFOpLambda)    (None, 64, 1)        0           ['tf.cast[0][0]']
#
#  frames (InputLayer)            [(None, 64, 66, 3)]  0           []
#
#  tf.compat.v1.shape (TFOpLambda  (3,)                0           ['tf.expand_dims[0][0]']
#  )
#
#  tf.slice (TFOpLambda)          (None, 64, 66, 2)    0           ['frames[0][0]']
#
#  tf.random.uniform (TFOpLambda)  (None, 64, 1)       0           ['tf.compat.v1.shape[0][0]']
#
#  tf.slice_1 (TFOpLambda)        (None, 64, 40, 2)    0           ['tf.slice[0][0]']
#
#  tf.slice_2 (TFOpLambda)        (None, 64, 21, 2)    0           ['tf.slice[0][0]']
#
#  tf.slice_3 (TFOpLambda)        (None, 64, 5, 2)     0           ['tf.slice[0][0]']
#
#  tf.math.greater (TFOpLambda)   (None, 64, 1)        0           ['tf.random.uniform[0][0]']
#
#  tf.math.not_equal_1 (TFOpLambd  (None, 64, 1)       0           ['tf.expand_dims[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLambda)  (None, 64, 40, 2)    0           ['tf.slice_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 64, 21, 2)   0           ['tf.slice_2[0][0]']
#  )
#
#  tf.math.subtract_2 (TFOpLambda  (None, 64, 5, 2)    0           ['tf.slice_3[0][0]']
#  )
#
#  tf.math.logical_and (TFOpLambd  (None, 64, 1)       0           ['tf.math.greater[0][0]',
#  a)                                                               'tf.math.not_equal_1[0][0]']
#
#  tf.math.equal_1 (TFOpLambda)   (None, 64, 40, 2)    0           ['tf.slice_1[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 64, 40, 2)    0           ['tf.math.subtract[0][0]']
#
#  tf.math.equal_2 (TFOpLambda)   (None, 64, 21, 2)    0           ['tf.slice_2[0][0]']
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 64, 21, 2)   0           ['tf.math.subtract_1[0][0]']
#
#  tf.math.equal_3 (TFOpLambda)   (None, 64, 5, 2)     0           ['tf.slice_3[0][0]']
#
#  tf.math.truediv_2 (TFOpLambda)  (None, 64, 5, 2)    0           ['tf.math.subtract_2[0][0]']
#
#  tf.where (TFOpLambda)          (None, 64, 1)        0           ['tf.math.logical_and[0][0]']
#
#  tf.where_2 (TFOpLambda)        (None, 64, 40, 2)    0           ['tf.math.equal_1[0][0]',
#                                                                   'tf.math.truediv[0][0]']
#
#  tf.where_3 (TFOpLambda)        (None, 64, 21, 2)    0           ['tf.math.equal_2[0][0]',
#                                                                   'tf.math.truediv_1[0][0]']
#
#  tf.where_4 (TFOpLambda)        (None, 64, 5, 2)     0           ['tf.math.equal_3[0][0]',
#                                                                   'tf.math.truediv_2[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None, 1, 1)        0           ['tf.where[0][0]']
#  )
#
#  tf.reshape (TFOpLambda)        (None, 64, 80)       0           ['tf.where_2[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 64, 42)       0           ['tf.where_3[0][0]']
#
#  tf.reshape_2 (TFOpLambda)      (None, 64, 10)       0           ['tf.where_4[0][0]']
#
#  tf.math.equal (TFOpLambda)     (None, 1, 1)         0           ['tf.math.reduce_sum[0][0]']
#
#  embedding (Embedding)          (None, 64, 512)      986243      ['tf.reshape[0][0]',
#                                                                   'tf.reshape_1[0][0]',
#                                                                   'tf.reshape_2[0][0]',
#                                                                   'non_empty_frame_idxs[0][0]']
#
#  tf.where_1 (TFOpLambda)        (None, 64, 1)        0           ['tf.math.equal[0][0]',
#                                                                   'tf.expand_dims[0][0]',
#                                                                   'tf.where[0][0]']
#
#  transformer (Transformer)      (None, 64, 512)      6300672     ['embedding[0][0]',
#                                                                   'tf.where_1[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 64, 512)      0           ['transformer[0][0]',
#                                                                   'tf.where_1[0][0]']
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None, 512)         0           ['tf.math.multiply[0][0]']
#  da)
#
#  tf.math.reduce_sum_2 (TFOpLamb  (None, 1)           0           ['tf.where_1[0][0]']
#  da)
#
#  tf.math.truediv_3 (TFOpLambda)  (None, 512)         0           ['tf.math.reduce_sum_1[0][0]',
#                                                                   'tf.math.reduce_sum_2[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['tf.math.truediv_3[0][0]']
#
#  dense (Dense)                  (None, 250)          128250      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7,415,165
# Trainable params: 7,415,165
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 1: LearningRateScheduler setting learning rate to 8.881784197001253e-19.
# learning rate: 8.88e-19, weight decay: 4.44e-20
# Epoch 1/100
# 96/96 [==============================] - 100s 866ms/step - loss: 5.5770 - acc: 0.0036 - top_5_acc: 0.0178 - top_10_acc: 0.0383 - val_loss: 5.5318 - val_acc: 0.0049 - val_top_5_acc: 0.0166 - val_top_10_acc: 0.0339 - lr: 8.8818e-19
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.7763568394002505e-18.
# learning rate: 1.78e-18, weight decay: 8.88e-20
# Epoch 2/100
# 96/96 [==============================] - 84s 876ms/step - loss: 5.5758 - acc: 0.0038 - top_5_acc: 0.0186 - top_10_acc: 0.0386 - val_loss: 5.5317 - val_acc: 0.0049 - val_top_5_acc: 0.0167 - val_top_10_acc: 0.0335 - lr: 1.7764e-18
#
# Epoch 3: LearningRateScheduler setting learning rate to 3.552713678800501e-18.
# learning rate: 3.55e-18, weight decay: 1.78e-19
# Epoch 3/100
# 96/96 [==============================] - 85s 882ms/step - loss: 5.5763 - acc: 0.0038 - top_5_acc: 0.0187 - top_10_acc: 0.0389 - val_loss: 5.5317 - val_acc: 0.0049 - val_top_5_acc: 0.0170 - val_top_10_acc: 0.0349 - lr: 3.5527e-18
#
# Epoch 4: LearningRateScheduler setting learning rate to 7.105427357601002e-18.
# learning rate: 7.11e-18, weight decay: 3.55e-19
# Epoch 4/100
# 96/96 [==============================] - 87s 905ms/step - loss: 5.5757 - acc: 0.0038 - top_5_acc: 0.0188 - top_10_acc: 0.0375 - val_loss: 5.5318 - val_acc: 0.0051 - val_top_5_acc: 0.0158 - val_top_10_acc: 0.0340 - lr: 7.1054e-18
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.4210854715202004e-17.
# learning rate: 1.42e-17, weight decay: 7.11e-19
# Epoch 5/100
# 96/96 [==============================] - 87s 910ms/step - loss: 5.5753 - acc: 0.0039 - top_5_acc: 0.0191 - top_10_acc: 0.0391 - val_loss: 5.5318 - val_acc: 0.0050 - val_top_5_acc: 0.0168 - val_top_10_acc: 0.0348 - lr: 1.4211e-17
#
# Epoch 6: LearningRateScheduler setting learning rate to 2.842170943040401e-17.
# learning rate: 2.84e-17, weight decay: 1.42e-18
# Epoch 6/100
# 96/96 [==============================] - 86s 898ms/step - loss: 5.5757 - acc: 0.0038 - top_5_acc: 0.0185 - top_10_acc: 0.0378 - val_loss: 5.5316 - val_acc: 0.0050 - val_top_5_acc: 0.0170 - val_top_10_acc: 0.0342 - lr: 2.8422e-17
#
# Epoch 7: LearningRateScheduler setting learning rate to 5.684341886080802e-17.
# learning rate: 5.68e-17, weight decay: 2.84e-18
# Epoch 7/100
# 96/96 [==============================] - 86s 900ms/step - loss: 5.5774 - acc: 0.0036 - top_5_acc: 0.0182 - top_10_acc: 0.0378 - val_loss: 5.5317 - val_acc: 0.0048 - val_top_5_acc: 0.0164 - val_top_10_acc: 0.0344 - lr: 5.6843e-17
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.1368683772161603e-16.
# learning rate: 1.14e-16, weight decay: 5.68e-18
# Epoch 8/100
# 96/96 [==============================] - 87s 910ms/step - loss: 5.5754 - acc: 0.0038 - top_5_acc: 0.0192 - top_10_acc: 0.0387 - val_loss: 5.5317 - val_acc: 0.0047 - val_top_5_acc: 0.0169 - val_top_10_acc: 0.0341 - lr: 1.1369e-16
#
# Epoch 9: LearningRateScheduler setting learning rate to 2.2737367544323206e-16.
# learning rate: 2.27e-16, weight decay: 1.14e-17
# Epoch 9/100
# 96/96 [==============================] - 89s 925ms/step - loss: 5.5770 - acc: 0.0039 - top_5_acc: 0.0190 - top_10_acc: 0.0382 - val_loss: 5.5316 - val_acc: 0.0050 - val_top_5_acc: 0.0169 - val_top_10_acc: 0.0345 - lr: 2.2737e-16
#
# Epoch 10: LearningRateScheduler setting learning rate to 4.547473508864641e-16.
# learning rate: 4.55e-16, weight decay: 2.27e-17
# Epoch 10/100
# 96/96 [==============================] - 88s 913ms/step - loss: 5.5769 - acc: 0.0038 - top_5_acc: 0.0187 - top_10_acc: 0.0382 - val_loss: 5.5317 - val_acc: 0.0049 - val_top_5_acc: 0.0161 - val_top_10_acc: 0.0336 - lr: 4.5475e-16
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.094947017729283e-16.
# learning rate: 9.09e-16, weight decay: 4.55e-17
# Epoch 11/100
# 96/96 [==============================] - 89s 924ms/step - loss: 5.5753 - acc: 0.0036 - top_5_acc: 0.0189 - top_10_acc: 0.0381 - val_loss: 5.5319 - val_acc: 0.0048 - val_top_5_acc: 0.0168 - val_top_10_acc: 0.0342 - lr: 9.0949e-16
#
# Epoch 12: LearningRateScheduler setting learning rate to 1.8189894035458565e-15.
# learning rate: 1.82e-15, weight decay: 9.09e-17
# Epoch 12/100
# 96/96 [==============================] - 89s 923ms/step - loss: 5.5766 - acc: 0.0035 - top_5_acc: 0.0192 - top_10_acc: 0.0386 - val_loss: 5.5317 - val_acc: 0.0049 - val_top_5_acc: 0.0165 - val_top_10_acc: 0.0343 - lr: 1.8190e-15
#
# Epoch 13: LearningRateScheduler setting learning rate to 3.637978807091713e-15.
# learning rate: 3.64e-15, weight decay: 1.82e-16
# Epoch 13/100
# 96/96 [==============================] - 89s 923ms/step - loss: 5.5775 - acc: 0.0036 - top_5_acc: 0.0177 - top_10_acc: 0.0373 - val_loss: 5.5317 - val_acc: 0.0048 - val_top_5_acc: 0.0169 - val_top_10_acc: 0.0348 - lr: 3.6380e-15
#
# Epoch 14: LearningRateScheduler setting learning rate to 7.275957614183426e-15.
# learning rate: 7.28e-15, weight decay: 3.64e-16
# Epoch 14/100
# 96/96 [==============================] - 88s 922ms/step - loss: 5.5757 - acc: 0.0034 - top_5_acc: 0.0183 - top_10_acc: 0.0382 - val_loss: 5.5318 - val_acc: 0.0052 - val_top_5_acc: 0.0167 - val_top_10_acc: 0.0342 - lr: 7.2760e-15
#
# Epoch 15: LearningRateScheduler setting learning rate to 1.4551915228366852e-14.
# learning rate: 1.46e-14, weight decay: 7.28e-16
# Epoch 15/100
# 96/96 [==============================] - 87s 910ms/step - loss: 5.5769 - acc: 0.0036 - top_5_acc: 0.0185 - top_10_acc: 0.0385 - val_loss: 5.5317 - val_acc: 0.0049 - val_top_5_acc: 0.0167 - val_top_10_acc: 0.0349 - lr: 1.4552e-14
#
# Epoch 16: LearningRateScheduler setting learning rate to 2.9103830456733704e-14.
# learning rate: 2.91e-14, weight decay: 1.46e-15
# Epoch 16/100
# 96/96 [==============================] - 89s 923ms/step - loss: 5.5755 - acc: 0.0035 - top_5_acc: 0.0189 - top_10_acc: 0.0384 - val_loss: 5.5318 - val_acc: 0.0048 - val_top_5_acc: 0.0165 - val_top_10_acc: 0.0347 - lr: 2.9104e-14
#
# Epoch 17: LearningRateScheduler setting learning rate to 5.820766091346741e-14.
# learning rate: 5.82e-14, weight decay: 2.91e-15
# Epoch 17/100
# 96/96 [==============================] - 88s 913ms/step - loss: 5.5766 - acc: 0.0037 - top_5_acc: 0.0187 - top_10_acc: 0.0381 - val_loss: 5.5318 - val_acc: 0.0048 - val_top_5_acc: 0.0167 - val_top_10_acc: 0.0338 - lr: 5.8208e-14
#
# Epoch 18: LearningRateScheduler setting learning rate to 1.1641532182693482e-13.
# learning rate: 1.16e-13, weight decay: 5.82e-15
# Epoch 18/100
# 96/96 [==============================] - 87s 910ms/step - loss: 5.5767 - acc: 0.0037 - top_5_acc: 0.0187 - top_10_acc: 0.0377 - val_loss: 5.5317 - val_acc: 0.0046 - val_top_5_acc: 0.0167 - val_top_10_acc: 0.0354 - lr: 1.1642e-13
#
# Epoch 19: LearningRateScheduler setting learning rate to 2.3283064365386963e-13.
# learning rate: 2.33e-13, weight decay: 1.16e-14
# Epoch 19/100
# 96/96 [==============================] - 87s 908ms/step - loss: 5.5769 - acc: 0.0035 - top_5_acc: 0.0182 - top_10_acc: 0.0380 - val_loss: 5.5317 - val_acc: 0.0049 - val_top_5_acc: 0.0166 - val_top_10_acc: 0.0349 - lr: 2.3283e-13
#
# Epoch 20: LearningRateScheduler setting learning rate to 4.656612873077393e-13.
# learning rate: 4.66e-13, weight decay: 2.33e-14
# Epoch 20/100
# 96/96 [==============================] - 89s 924ms/step - loss: 5.5768 - acc: 0.0040 - top_5_acc: 0.0189 - top_10_acc: 0.0387 - val_loss: 5.5317 - val_acc: 0.0050 - val_top_5_acc: 0.0167 - val_top_10_acc: 0.0338 - lr: 4.6566e-13
#
# Epoch 21: LearningRateScheduler setting learning rate to 9.313225746154785e-13.
# learning rate: 9.31e-13, weight decay: 4.66e-14
# Epoch 21/100
# 96/96 [==============================] - 89s 923ms/step - loss: 5.5759 - acc: 0.0037 - top_5_acc: 0.0181 - top_10_acc: 0.0376 - val_loss: 5.5318 - val_acc: 0.0050 - val_top_5_acc: 0.0171 - val_top_10_acc: 0.0335 - lr: 9.3132e-13
#
# Epoch 22: LearningRateScheduler setting learning rate to 1.862645149230957e-12.
# learning rate: 1.86e-12, weight decay: 9.31e-14
# Epoch 22/100
# 96/96 [==============================] - 88s 922ms/step - loss: 5.5761 - acc: 0.0039 - top_5_acc: 0.0189 - top_10_acc: 0.0386 - val_loss: 5.5319 - val_acc: 0.0050 - val_top_5_acc: 0.0163 - val_top_10_acc: 0.0344 - lr: 1.8626e-12
#
# Epoch 23: LearningRateScheduler setting learning rate to 3.725290298461914e-12.
# learning rate: 3.73e-12, weight decay: 1.86e-13
# Epoch 23/100
# 96/96 [==============================] - 87s 906ms/step - loss: 5.5756 - acc: 0.0035 - top_5_acc: 0.0189 - top_10_acc: 0.0383 - val_loss: 5.5317 - val_acc: 0.0047 - val_top_5_acc: 0.0164 - val_top_10_acc: 0.0350 - lr: 3.7253e-12
#
# Epoch 24: LearningRateScheduler setting learning rate to 7.450580596923828e-12.
# learning rate: 7.45e-12, weight decay: 3.73e-13
# Epoch 24/100
# 96/96 [==============================] - 88s 918ms/step - loss: 5.5735 - acc: 0.0038 - top_5_acc: 0.0190 - top_10_acc: 0.0386 - val_loss: 5.5318 - val_acc: 0.0048 - val_top_5_acc: 0.0169 - val_top_10_acc: 0.0340 - lr: 7.4506e-12
#
# Epoch 25: LearningRateScheduler setting learning rate to 1.4901161193847657e-11.
# learning rate: 1.49e-11, weight decay: 7.45e-13
# Epoch 25/100
# 96/96 [==============================] - 88s 915ms/step - loss: 5.5763 - acc: 0.0036 - top_5_acc: 0.0183 - top_10_acc: 0.0382 - val_loss: 5.5317 - val_acc: 0.0050 - val_top_5_acc: 0.0163 - val_top_10_acc: 0.0349 - lr: 1.4901e-11
#
# Epoch 26: LearningRateScheduler setting learning rate to 2.980232238769531e-11.
# learning rate: 2.98e-11, weight decay: 1.49e-12
# Epoch 26/100
# 96/96 [==============================] - 88s 915ms/step - loss: 5.5764 - acc: 0.0037 - top_5_acc: 0.0192 - top_10_acc: 0.0386 - val_loss: 5.5316 - val_acc: 0.0048 - val_top_5_acc: 0.0164 - val_top_10_acc: 0.0337 - lr: 2.9802e-11
#
# Epoch 27: LearningRateScheduler setting learning rate to 5.960464477539063e-11.
# learning rate: 5.96e-11, weight decay: 2.98e-12
# Epoch 27/100
# 96/96 [==============================] - 88s 916ms/step - loss: 5.5768 - acc: 0.0035 - top_5_acc: 0.0181 - top_10_acc: 0.0377 - val_loss: 5.5316 - val_acc: 0.0050 - val_top_5_acc: 0.0170 - val_top_10_acc: 0.0344 - lr: 5.9605e-11
#
# Epoch 28: LearningRateScheduler setting learning rate to 1.1920928955078125e-10.
# learning rate: 1.19e-10, weight decay: 5.96e-12
# Epoch 28/100
# 96/96 [==============================] - 87s 903ms/step - loss: 5.5779 - acc: 0.0039 - top_5_acc: 0.0183 - top_10_acc: 0.0377 - val_loss: 5.5318 - val_acc: 0.0047 - val_top_5_acc: 0.0163 - val_top_10_acc: 0.0345 - lr: 1.1921e-10
#
# Epoch 29: LearningRateScheduler setting learning rate to 2.384185791015625e-10.
# learning rate: 2.38e-10, weight decay: 1.19e-11
# Epoch 29/100
# 96/96 [==============================] - 88s 916ms/step - loss: 5.5757 - acc: 0.0042 - top_5_acc: 0.0193 - top_10_acc: 0.0391 - val_loss: 5.5317 - val_acc: 0.0051 - val_top_5_acc: 0.0168 - val_top_10_acc: 0.0342 - lr: 2.3842e-10
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.76837158203125e-10.
# learning rate: 4.77e-10, weight decay: 2.38e-11
# Epoch 30/100
# 96/96 [==============================] - 88s 915ms/step - loss: 5.5756 - acc: 0.0034 - top_5_acc: 0.0184 - top_10_acc: 0.0380 - val_loss: 5.5317 - val_acc: 0.0050 - val_top_5_acc: 0.0170 - val_top_10_acc: 0.0337 - lr: 4.7684e-10
#
# Epoch 31: LearningRateScheduler setting learning rate to 9.5367431640625e-10.
# learning rate: 9.54e-10, weight decay: 4.77e-11
# Epoch 31/100
# 96/96 [==============================] - 88s 916ms/step - loss: 5.5743 - acc: 0.0039 - top_5_acc: 0.0195 - top_10_acc: 0.0396 - val_loss: 5.5317 - val_acc: 0.0048 - val_top_5_acc: 0.0167 - val_top_10_acc: 0.0347 - lr: 9.5367e-10
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.9073486328125e-09.
# learning rate: 1.91e-09, weight decay: 9.54e-11
# Epoch 32/100
# 96/96 [==============================] - 87s 903ms/step - loss: 5.5755 - acc: 0.0041 - top_5_acc: 0.0183 - top_10_acc: 0.0392 - val_loss: 5.5316 - val_acc: 0.0050 - val_top_5_acc: 0.0167 - val_top_10_acc: 0.0348 - lr: 1.9073e-09
#
# Epoch 33: LearningRateScheduler setting learning rate to 3.814697265625e-09.
# learning rate: 3.81e-09, weight decay: 1.91e-10
# Epoch 33/100
# 96/96 [==============================] - 88s 917ms/step - loss: 5.5764 - acc: 0.0038 - top_5_acc: 0.0187 - top_10_acc: 0.0379 - val_loss: 5.5317 - val_acc: 0.0051 - val_top_5_acc: 0.0170 - val_top_10_acc: 0.0343 - lr: 3.8147e-09
#
# Epoch 34: LearningRateScheduler setting learning rate to 7.62939453125e-09.
# learning rate: 7.63e-09, weight decay: 3.81e-10
# Epoch 34/100
# 96/96 [==============================] - 88s 915ms/step - loss: 5.5753 - acc: 0.0040 - top_5_acc: 0.0187 - top_10_acc: 0.0377 - val_loss: 5.5317 - val_acc: 0.0049 - val_top_5_acc: 0.0162 - val_top_10_acc: 0.0336 - lr: 7.6294e-09
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.52587890625e-08.
# learning rate: 1.53e-08, weight decay: 7.63e-10
# Epoch 35/100
# 96/96 [==============================] - 88s 916ms/step - loss: 5.5776 - acc: 0.0041 - top_5_acc: 0.0194 - top_10_acc: 0.0388 - val_loss: 5.5315 - val_acc: 0.0049 - val_top_5_acc: 0.0164 - val_top_10_acc: 0.0335 - lr: 1.5259e-08
#
# Epoch 36: LearningRateScheduler setting learning rate to 3.0517578125e-08.
# learning rate: 3.05e-08, weight decay: 1.53e-09
# Epoch 36/100
# 96/96 [==============================] - 87s 903ms/step - loss: 5.5741 - acc: 0.0034 - top_5_acc: 0.0178 - top_10_acc: 0.0380 - val_loss: 5.5312 - val_acc: 0.0048 - val_top_5_acc: 0.0168 - val_top_10_acc: 0.0343 - lr: 3.0518e-08
#
# Epoch 37: LearningRateScheduler setting learning rate to 6.103515625e-08.
# learning rate: 6.10e-08, weight decay: 3.05e-09
# Epoch 37/100
# 96/96 [==============================] - 88s 916ms/step - loss: 5.5723 - acc: 0.0040 - top_5_acc: 0.0197 - top_10_acc: 0.0394 - val_loss: 5.5307 - val_acc: 0.0051 - val_top_5_acc: 0.0174 - val_top_10_acc: 0.0343 - lr: 6.1035e-08
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.220703125e-07.
# learning rate: 1.22e-07, weight decay: 6.10e-09
# Epoch 38/100
# 96/96 [==============================] - 87s 903ms/step - loss: 5.5718 - acc: 0.0038 - top_5_acc: 0.0197 - top_10_acc: 0.0396 - val_loss: 5.5295 - val_acc: 0.0049 - val_top_5_acc: 0.0168 - val_top_10_acc: 0.0349 - lr: 1.2207e-07
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.44140625e-07.
# learning rate: 2.44e-07, weight decay: 1.22e-08
# Epoch 39/100
# 96/96 [==============================] - 87s 903ms/step - loss: 5.5668 - acc: 0.0041 - top_5_acc: 0.0201 - top_10_acc: 0.0406 - val_loss: 5.5274 - val_acc: 0.0052 - val_top_5_acc: 0.0172 - val_top_10_acc: 0.0366 - lr: 2.4414e-07
#
# Epoch 40: LearningRateScheduler setting learning rate to 4.8828125e-07.
# learning rate: 4.88e-07, weight decay: 2.44e-08
# Epoch 40/100
# 96/96 [==============================] - 87s 904ms/step - loss: 5.5598 - acc: 0.0041 - top_5_acc: 0.0200 - top_10_acc: 0.0417 - val_loss: 5.5235 - val_acc: 0.0050 - val_top_5_acc: 0.0186 - val_top_10_acc: 0.0384 - lr: 4.8828e-07
#
# Epoch 41: LearningRateScheduler setting learning rate to 9.765625e-07.
# learning rate: 9.77e-07, weight decay: 4.88e-08
# Epoch 41/100
# 96/96 [==============================] - 88s 917ms/step - loss: 5.5472 - acc: 0.0039 - top_5_acc: 0.0217 - top_10_acc: 0.0436 - val_loss: 5.5159 - val_acc: 0.0053 - val_top_5_acc: 0.0240 - val_top_10_acc: 0.0481 - lr: 9.7656e-07
#
# Epoch 42: LearningRateScheduler setting learning rate to 1.953125e-06.
# learning rate: 1.95e-06, weight decay: 9.77e-08
# Epoch 42/100
# 96/96 [==============================] - 87s 903ms/step - loss: 5.5253 - acc: 0.0056 - top_5_acc: 0.0279 - top_10_acc: 0.0555 - val_loss: 5.5013 - val_acc: 0.0088 - val_top_5_acc: 0.0341 - val_top_10_acc: 0.0617 - lr: 1.9531e-06
#
# Epoch 43: LearningRateScheduler setting learning rate to 3.90625e-06.
# learning rate: 3.91e-06, weight decay: 1.95e-07
# Epoch 43/100
# 96/96 [==============================] - 88s 916ms/step - loss: 5.4913 - acc: 0.0100 - top_5_acc: 0.0423 - top_10_acc: 0.0785 - val_loss: 5.4688 - val_acc: 0.0145 - val_top_5_acc: 0.0513 - val_top_10_acc: 0.1016 - lr: 3.9063e-06
#
# Epoch 44: LearningRateScheduler setting learning rate to 7.8125e-06.
# learning rate: 7.81e-06, weight decay: 3.91e-07
# Epoch 44/100
# 96/96 [==============================] - 88s 914ms/step - loss: 5.4300 - acc: 0.0138 - top_5_acc: 0.0602 - top_10_acc: 0.1086 - val_loss: 5.3963 - val_acc: 0.0133 - val_top_5_acc: 0.0663 - val_top_10_acc: 0.1290 - lr: 7.8125e-06
#
# Epoch 45: LearningRateScheduler setting learning rate to 1.5625e-05.
# learning rate: 1.56e-05, weight decay: 7.81e-07
# Epoch 45/100
# 96/96 [==============================] - 88s 912ms/step - loss: 5.3484 - acc: 0.0242 - top_5_acc: 0.0911 - top_10_acc: 0.1578 - val_loss: 5.3022 - val_acc: 0.0221 - val_top_5_acc: 0.1183 - val_top_10_acc: 0.1977 - lr: 1.5625e-05
#
# Epoch 46: LearningRateScheduler setting learning rate to 3.125e-05.
# learning rate: 3.13e-05, weight decay: 1.56e-06
# Epoch 46/100
# 96/96 [==============================] - 87s 902ms/step - loss: 5.1615 - acc: 0.0568 - top_5_acc: 0.1883 - top_10_acc: 0.2912 - val_loss: 4.9930 - val_acc: 0.1004 - val_top_5_acc: 0.3056 - val_top_10_acc: 0.4351 - lr: 3.1250e-05
#
# Epoch 47: LearningRateScheduler setting learning rate to 6.25e-05.
# learning rate: 6.25e-05, weight decay: 3.13e-06
# Epoch 47/100
# 96/96 [==============================] - 87s 903ms/step - loss: 4.7332 - acc: 0.1474 - top_5_acc: 0.3848 - top_10_acc: 0.5182 - val_loss: 4.3657 - val_acc: 0.2578 - val_top_5_acc: 0.5749 - val_top_10_acc: 0.7049 - lr: 6.2500e-05
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.000125.
# learning rate: 1.25e-04, weight decay: 6.25e-06
# Epoch 48/100
# 96/96 [==============================] - 88s 916ms/step - loss: 4.1520 - acc: 0.3112 - top_5_acc: 0.6079 - top_10_acc: 0.7219 - val_loss: 3.7501 - val_acc: 0.4345 - val_top_5_acc: 0.7486 - val_top_10_acc: 0.8445 - lr: 1.2500e-04
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.00025.
# learning rate: 2.50e-04, weight decay: 1.25e-05
# Epoch 49/100
# 96/96 [==============================] - 88s 921ms/step - loss: 3.6444 - acc: 0.4657 - top_5_acc: 0.7510 - top_10_acc: 0.8344 - val_loss: 3.3437 - val_acc: 0.5519 - val_top_5_acc: 0.8293 - val_top_10_acc: 0.9000 - lr: 2.5000e-04
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0005.
# learning rate: 5.00e-04, weight decay: 2.50e-05
# Epoch 50/100
# 96/96 [==============================] - 87s 911ms/step - loss: 3.3314 - acc: 0.5670 - top_5_acc: 0.8232 - top_10_acc: 0.8836 - val_loss: 3.1896 - val_acc: 0.5898 - val_top_5_acc: 0.8551 - val_top_10_acc: 0.9188 - lr: 5.0000e-04
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.001.
# learning rate: 1.00e-03, weight decay: 5.00e-05
# Epoch 51/100
# 96/96 [==============================] - 89s 925ms/step - loss: 3.1753 - acc: 0.6191 - top_5_acc: 0.8566 - top_10_acc: 0.9065 - val_loss: 3.1133 - val_acc: 0.6220 - val_top_5_acc: 0.8692 - val_top_10_acc: 0.9227 - lr: 0.0010
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.0009990133642141358.
# learning rate: 9.99e-04, weight decay: 5.00e-05
# Epoch 52/100
# 96/96 [==============================] - 88s 914ms/step - loss: 2.9209 - acc: 0.7128 - top_5_acc: 0.9043 - top_10_acc: 0.9381 - val_loss: 3.0776 - val_acc: 0.6298 - val_top_5_acc: 0.8742 - val_top_10_acc: 0.9260 - lr: 9.9901e-04
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.000996057350657239.
# learning rate: 9.96e-04, weight decay: 4.98e-05
# Epoch 53/100
# 96/96 [==============================] - 88s 912ms/step - loss: 2.7878 - acc: 0.7636 - top_5_acc: 0.9272 - top_10_acc: 0.9504 - val_loss: 2.9767 - val_acc: 0.6618 - val_top_5_acc: 0.8969 - val_top_10_acc: 0.9398 - lr: 9.9606e-04
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0009911436253643444.
# learning rate: 9.91e-04, weight decay: 4.96e-05
# Epoch 54/100
# 96/96 [==============================] - 87s 912ms/step - loss: 2.7022 - acc: 0.7950 - top_5_acc: 0.9385 - top_10_acc: 0.9588 - val_loss: 2.9365 - val_acc: 0.6767 - val_top_5_acc: 0.9018 - val_top_10_acc: 0.9402 - lr: 9.9114e-04
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.0009842915805643156.
# learning rate: 9.84e-04, weight decay: 4.92e-05
# Epoch 55/100
# 96/96 [==============================] - 89s 925ms/step - loss: 2.6274 - acc: 0.8229 - top_5_acc: 0.9496 - top_10_acc: 0.9665 - val_loss: 2.9328 - val_acc: 0.6772 - val_top_5_acc: 0.9004 - val_top_10_acc: 0.9389 - lr: 9.8429e-04
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0009755282581475768.
# learning rate: 9.76e-04, weight decay: 4.88e-05
# Epoch 56/100
# 96/96 [==============================] - 89s 926ms/step - loss: 2.5576 - acc: 0.8489 - top_5_acc: 0.9591 - top_10_acc: 0.9733 - val_loss: 2.8812 - val_acc: 0.6964 - val_top_5_acc: 0.9070 - val_top_10_acc: 0.9434 - lr: 9.7553e-04
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.0009648882429441257.
# learning rate: 9.65e-04, weight decay: 4.82e-05
# Epoch 57/100
# 96/96 [==============================] - 88s 913ms/step - loss: 2.5030 - acc: 0.8693 - top_5_acc: 0.9657 - top_10_acc: 0.9773 - val_loss: 2.9320 - val_acc: 0.6867 - val_top_5_acc: 0.8964 - val_top_10_acc: 0.9331 - lr: 9.6489e-04
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0009524135262330098.
# learning rate: 9.52e-04, weight decay: 4.76e-05
# Epoch 58/100
# 96/96 [==============================] - 89s 925ms/step - loss: 2.4648 - acc: 0.8839 - top_5_acc: 0.9713 - top_10_acc: 0.9814 - val_loss: 2.8942 - val_acc: 0.6954 - val_top_5_acc: 0.8970 - val_top_10_acc: 0.9354 - lr: 9.5241e-04
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0009381533400219318.
# learning rate: 9.38e-04, weight decay: 4.69e-05
# Epoch 59/100
# 96/96 [==============================] - 88s 912ms/step - loss: 2.4289 - acc: 0.8972 - top_5_acc: 0.9750 - top_10_acc: 0.9833 - val_loss: 2.8963 - val_acc: 0.6992 - val_top_5_acc: 0.8987 - val_top_10_acc: 0.9351 - lr: 9.3815e-04
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0009221639627510075.
# learning rate: 9.22e-04, weight decay: 4.61e-05
# Epoch 60/100
# 96/96 [==============================] - 88s 913ms/step - loss: 2.3947 - acc: 0.9084 - top_5_acc: 0.9793 - top_10_acc: 0.9863 - val_loss: 2.8902 - val_acc: 0.7002 - val_top_5_acc: 0.9047 - val_top_10_acc: 0.9390 - lr: 9.2216e-04
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.0009045084971874737.
# learning rate: 9.05e-04, weight decay: 4.52e-05
# Epoch 61/100
# 96/96 [==============================] - 89s 925ms/step - loss: 2.3612 - acc: 0.9216 - top_5_acc: 0.9827 - top_10_acc: 0.9889 - val_loss: 2.8685 - val_acc: 0.7102 - val_top_5_acc: 0.9044 - val_top_10_acc: 0.9367 - lr: 9.0451e-04
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.0008852566213878947.
# learning rate: 8.85e-04, weight decay: 4.43e-05
# Epoch 62/100
# 96/96 [==============================] - 89s 926ms/step - loss: 2.3285 - acc: 0.9317 - top_5_acc: 0.9863 - top_10_acc: 0.9911 - val_loss: 2.8859 - val_acc: 0.7090 - val_top_5_acc: 0.8991 - val_top_10_acc: 0.9351 - lr: 8.8526e-04
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0008644843137107057.
# learning rate: 8.64e-04, weight decay: 4.32e-05
# Epoch 63/100
# 96/96 [==============================] - 88s 921ms/step - loss: 2.3039 - acc: 0.9397 - top_5_acc: 0.9882 - top_10_acc: 0.9928 - val_loss: 2.8778 - val_acc: 0.7061 - val_top_5_acc: 0.9012 - val_top_10_acc: 0.9373 - lr: 8.6448e-04
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.0008422735529643444.
# learning rate: 8.42e-04, weight decay: 4.21e-05
# Epoch 64/100
# 96/96 [==============================] - 88s 921ms/step - loss: 2.2795 - acc: 0.9485 - top_5_acc: 0.9904 - top_10_acc: 0.9944 - val_loss: 2.8917 - val_acc: 0.6991 - val_top_5_acc: 0.9013 - val_top_10_acc: 0.9359 - lr: 8.4227e-04
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0008187119948743449.
# learning rate: 8.19e-04, weight decay: 4.09e-05
# Epoch 65/100
# 96/96 [==============================] - 88s 920ms/step - loss: 2.2633 - acc: 0.9527 - top_5_acc: 0.9927 - top_10_acc: 0.9956 - val_loss: 2.8734 - val_acc: 0.7108 - val_top_5_acc: 0.9044 - val_top_10_acc: 0.9384 - lr: 8.1871e-04
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.0007938926261462366.
# learning rate: 7.94e-04, weight decay: 3.97e-05
# Epoch 66/100
# 96/96 [==============================] - 88s 918ms/step - loss: 2.2410 - acc: 0.9610 - top_5_acc: 0.9940 - top_10_acc: 0.9964 - val_loss: 2.8682 - val_acc: 0.7080 - val_top_5_acc: 0.9041 - val_top_10_acc: 0.9378 - lr: 7.9389e-04
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0007679133974894983.
# learning rate: 7.68e-04, weight decay: 3.84e-05
# Epoch 67/100
# 96/96 [==============================] - 88s 917ms/step - loss: 2.2255 - acc: 0.9649 - top_5_acc: 0.9950 - top_10_acc: 0.9970 - val_loss: 2.8987 - val_acc: 0.7004 - val_top_5_acc: 0.8997 - val_top_10_acc: 0.9342 - lr: 7.6791e-04
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.0007408768370508576.
# learning rate: 7.41e-04, weight decay: 3.70e-05
# Epoch 68/100
# 96/96 [==============================] - 87s 905ms/step - loss: 2.2076 - acc: 0.9692 - top_5_acc: 0.9957 - top_10_acc: 0.9974 - val_loss: 2.8556 - val_acc: 0.7113 - val_top_5_acc: 0.9069 - val_top_10_acc: 0.9409 - lr: 7.4088e-04
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.0007128896457825364.
# learning rate: 7.13e-04, weight decay: 3.56e-05
# Epoch 69/100
# 96/96 [==============================] - 87s 905ms/step - loss: 2.1903 - acc: 0.9744 - top_5_acc: 0.9967 - top_10_acc: 0.9982 - val_loss: 2.8522 - val_acc: 0.7220 - val_top_5_acc: 0.9051 - val_top_10_acc: 0.9364 - lr: 7.1289e-04
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.0006840622763423391.
# learning rate: 6.84e-04, weight decay: 3.42e-05
# Epoch 70/100
# 96/96 [==============================] - 88s 917ms/step - loss: 2.1764 - acc: 0.9783 - top_5_acc: 0.9976 - top_10_acc: 0.9987 - val_loss: 2.8679 - val_acc: 0.7099 - val_top_5_acc: 0.9035 - val_top_10_acc: 0.9361 - lr: 6.8406e-04
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.0006545084971874737.
# learning rate: 6.55e-04, weight decay: 3.27e-05
# Epoch 71/100
# 96/96 [==============================] - 88s 918ms/step - loss: 2.1613 - acc: 0.9811 - top_5_acc: 0.9982 - top_10_acc: 0.9992 - val_loss: 2.8433 - val_acc: 0.7264 - val_top_5_acc: 0.9067 - val_top_10_acc: 0.9380 - lr: 6.5451e-04
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0006243449435824276.
# learning rate: 6.24e-04, weight decay: 3.12e-05
# Epoch 72/100
# 96/96 [==============================] - 88s 915ms/step - loss: 2.1475 - acc: 0.9843 - top_5_acc: 0.9986 - top_10_acc: 0.9994 - val_loss: 2.8516 - val_acc: 0.7219 - val_top_5_acc: 0.9060 - val_top_10_acc: 0.9369 - lr: 6.2434e-04
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0005936906572928624.
# learning rate: 5.94e-04, weight decay: 2.97e-05
# Epoch 73/100
# 96/96 [==============================] - 88s 912ms/step - loss: 2.1333 - acc: 0.9869 - top_5_acc: 0.9989 - top_10_acc: 0.9995 - val_loss: 2.8530 - val_acc: 0.7195 - val_top_5_acc: 0.9058 - val_top_10_acc: 0.9368 - lr: 5.9369e-04
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.0005626666167821521.
# learning rate: 5.63e-04, weight decay: 2.81e-05
# Epoch 74/100
# 96/96 [==============================] - 88s 915ms/step - loss: 2.1214 - acc: 0.9904 - top_5_acc: 0.9993 - top_10_acc: 0.9997 - val_loss: 2.8458 - val_acc: 0.7261 - val_top_5_acc: 0.9048 - val_top_10_acc: 0.9363 - lr: 5.6267e-04
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.0005313952597646568.
# learning rate: 5.31e-04, weight decay: 2.66e-05
# Epoch 75/100
# 96/96 [==============================] - 88s 916ms/step - loss: 2.1117 - acc: 0.9920 - top_5_acc: 0.9995 - top_10_acc: 0.9998 - val_loss: 2.8545 - val_acc: 0.7252 - val_top_5_acc: 0.9050 - val_top_10_acc: 0.9369 - lr: 5.3140e-04
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.0005.
# learning rate: 5.00e-04, weight decay: 2.50e-05
# Epoch 76/100
# 96/96 [==============================] - 88s 916ms/step - loss: 2.1047 - acc: 0.9925 - top_5_acc: 0.9997 - top_10_acc: 0.9999 - val_loss: 2.8242 - val_acc: 0.7290 - val_top_5_acc: 0.9107 - val_top_10_acc: 0.9392 - lr: 5.0000e-04
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.0004686047402353433.
# learning rate: 4.69e-04, weight decay: 2.34e-05
# Epoch 77/100
# 96/96 [==============================] - 86s 900ms/step - loss: 2.0964 - acc: 0.9941 - top_5_acc: 0.9997 - top_10_acc: 0.9999 - val_loss: 2.8533 - val_acc: 0.7286 - val_top_5_acc: 0.9035 - val_top_10_acc: 0.9338 - lr: 4.6860e-04
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.00043733338321784784.
# learning rate: 4.37e-04, weight decay: 2.19e-05
# Epoch 78/100
# 96/96 [==============================] - 88s 914ms/step - loss: 2.0890 - acc: 0.9952 - top_5_acc: 0.9998 - top_10_acc: 1.0000 - val_loss: 2.8421 - val_acc: 0.7240 - val_top_5_acc: 0.9075 - val_top_10_acc: 0.9398 - lr: 4.3733e-04
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.0004063093427071376.
# learning rate: 4.06e-04, weight decay: 2.03e-05
# Epoch 79/100
# 96/96 [==============================] - 87s 902ms/step - loss: 2.0813 - acc: 0.9961 - top_5_acc: 0.9999 - top_10_acc: 0.9999 - val_loss: 2.8291 - val_acc: 0.7359 - val_top_5_acc: 0.9111 - val_top_10_acc: 0.9413 - lr: 4.0631e-04
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.0003756550564175727.
# learning rate: 3.76e-04, weight decay: 1.88e-05
# Epoch 80/100
# 96/96 [==============================] - 88s 915ms/step - loss: 2.0746 - acc: 0.9970 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - val_loss: 2.8236 - val_acc: 0.7318 - val_top_5_acc: 0.9125 - val_top_10_acc: 0.9402 - lr: 3.7566e-04
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.00034549150281252633.
# learning rate: 3.45e-04, weight decay: 1.73e-05
# Epoch 81/100
# 96/96 [==============================] - 88s 914ms/step - loss: 2.0683 - acc: 0.9975 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8457 - val_acc: 0.7320 - val_top_5_acc: 0.9070 - val_top_10_acc: 0.9370 - lr: 3.4549e-04
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.00031593772365766105.
# learning rate: 3.16e-04, weight decay: 1.58e-05
# Epoch 82/100
# 96/96 [==============================] - 88s 913ms/step - loss: 2.0602 - acc: 0.9982 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - val_loss: 2.8332 - val_acc: 0.7352 - val_top_5_acc: 0.9113 - val_top_10_acc: 0.9408 - lr: 3.1594e-04
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.00028711035421746366.
# learning rate: 2.87e-04, weight decay: 1.44e-05
# Epoch 83/100
# 96/96 [==============================] - 88s 914ms/step - loss: 2.0553 - acc: 0.9986 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8532 - val_acc: 0.7281 - val_top_5_acc: 0.9065 - val_top_10_acc: 0.9351 - lr: 2.8711e-04
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0002591231629491423.
# learning rate: 2.59e-04, weight decay: 1.30e-05
# Epoch 84/100
# 96/96 [==============================] - 88s 915ms/step - loss: 2.0496 - acc: 0.9987 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8571 - val_acc: 0.7319 - val_top_5_acc: 0.9076 - val_top_10_acc: 0.9356 - lr: 2.5912e-04
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.00023208660251050156.
# learning rate: 2.32e-04, weight decay: 1.16e-05
# Epoch 85/100
# 96/96 [==============================] - 88s 913ms/step - loss: 2.0453 - acc: 0.9989 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8493 - val_acc: 0.7340 - val_top_5_acc: 0.9065 - val_top_10_acc: 0.9359 - lr: 2.3209e-04
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.00020610737385376348.
# learning rate: 2.06e-04, weight decay: 1.03e-05
# Epoch 86/100
# 96/96 [==============================] - 86s 901ms/step - loss: 2.0419 - acc: 0.9992 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8379 - val_acc: 0.7363 - val_top_5_acc: 0.9102 - val_top_10_acc: 0.9368 - lr: 2.0611e-04
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.00018128800512565513.
# learning rate: 1.81e-04, weight decay: 9.06e-06
# Epoch 87/100
# 96/96 [==============================] - 88s 914ms/step - loss: 2.0383 - acc: 0.9993 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8395 - val_acc: 0.7362 - val_top_5_acc: 0.9086 - val_top_10_acc: 0.9364 - lr: 1.8129e-04
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.00015772644703565563.
# learning rate: 1.58e-04, weight decay: 7.89e-06
# Epoch 88/100
# 96/96 [==============================] - 88s 916ms/step - loss: 2.0352 - acc: 0.9995 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8522 - val_acc: 0.7364 - val_top_5_acc: 0.9090 - val_top_10_acc: 0.9363 - lr: 1.5773e-04
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.00013551568628929433.
# learning rate: 1.36e-04, weight decay: 6.78e-06
# Epoch 89/100
# 96/96 [==============================] - 88s 916ms/step - loss: 2.0321 - acc: 0.9996 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8437 - val_acc: 0.7369 - val_top_5_acc: 0.9071 - val_top_10_acc: 0.9342 - lr: 1.3552e-04
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.00011474337861210544.
# learning rate: 1.15e-04, weight decay: 5.74e-06
# Epoch 90/100
# 96/96 [==============================] - 88s 922ms/step - loss: 2.0293 - acc: 0.9996 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8426 - val_acc: 0.7375 - val_top_5_acc: 0.9101 - val_top_10_acc: 0.9380 - lr: 1.1474e-04
#
# Epoch 91: LearningRateScheduler setting learning rate to 9.549150281252633e-05.
# learning rate: 9.55e-05, weight decay: 4.77e-06
# Epoch 91/100
# 96/96 [==============================] - 88s 913ms/step - loss: 2.0271 - acc: 0.9997 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8438 - val_acc: 0.7397 - val_top_5_acc: 0.9107 - val_top_10_acc: 0.9365 - lr: 9.5492e-05
#
# Epoch 92: LearningRateScheduler setting learning rate to 7.783603724899258e-05.
# learning rate: 7.78e-05, weight decay: 3.89e-06
# Epoch 92/100
# 96/96 [==============================] - 89s 923ms/step - loss: 2.0254 - acc: 0.9998 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8417 - val_acc: 0.7415 - val_top_5_acc: 0.9095 - val_top_10_acc: 0.9361 - lr: 7.7836e-05
#
# Epoch 93: LearningRateScheduler setting learning rate to 6.184665997806832e-05.
# learning rate: 6.18e-05, weight decay: 3.09e-06
# Epoch 93/100
# 96/96 [==============================] - 87s 911ms/step - loss: 2.0229 - acc: 0.9998 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8378 - val_acc: 0.7413 - val_top_5_acc: 0.9095 - val_top_10_acc: 0.9366 - lr: 6.1847e-05
#
# Epoch 94: LearningRateScheduler setting learning rate to 4.758647376699032e-05.
# learning rate: 4.76e-05, weight decay: 2.38e-06
# Epoch 94/100
# 96/96 [==============================] - 88s 921ms/step - loss: 2.0219 - acc: 0.9998 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8458 - val_acc: 0.7410 - val_top_5_acc: 0.9084 - val_top_10_acc: 0.9343 - lr: 4.7586e-05
#
# Epoch 95: LearningRateScheduler setting learning rate to 3.5111757055874326e-05.
# learning rate: 3.51e-05, weight decay: 1.76e-06
# Epoch 95/100
# 96/96 [==============================] - 89s 924ms/step - loss: 2.0211 - acc: 0.9998 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8460 - val_acc: 0.7400 - val_top_5_acc: 0.9092 - val_top_10_acc: 0.9357 - lr: 3.5112e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 2.4471741852423235e-05.
# learning rate: 2.45e-05, weight decay: 1.22e-06
# Epoch 96/100
# 96/96 [==============================] - 88s 923ms/step - loss: 2.0201 - acc: 0.9998 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8433 - val_acc: 0.7397 - val_top_5_acc: 0.9107 - val_top_10_acc: 0.9366 - lr: 2.4472e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 1.5708419435684463e-05.
# learning rate: 1.57e-05, weight decay: 7.85e-07
# Epoch 97/100
# 96/96 [==============================] - 87s 912ms/step - loss: 2.0196 - acc: 0.9999 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8422 - val_acc: 0.7397 - val_top_5_acc: 0.9115 - val_top_10_acc: 0.9363 - lr: 1.5708e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 8.856374635655695e-06.
# learning rate: 8.86e-06, weight decay: 4.43e-07
# Epoch 98/100
# 96/96 [==============================] - 87s 910ms/step - loss: 2.0190 - acc: 0.9998 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8435 - val_acc: 0.7413 - val_top_5_acc: 0.9089 - val_top_10_acc: 0.9361 - lr: 8.8564e-06
#
# Epoch 99: LearningRateScheduler setting learning rate to 3.942649342761117e-06.
# learning rate: 3.94e-06, weight decay: 1.97e-07
# Epoch 99/100
# 96/96 [==============================] - 89s 923ms/step - loss: 2.0185 - acc: 0.9999 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8425 - val_acc: 0.7406 - val_top_5_acc: 0.9113 - val_top_10_acc: 0.9363 - lr: 3.9426e-06
#
# Epoch 100: LearningRateScheduler setting learning rate to 9.866357858642206e-07.
# learning rate: 9.87e-07, weight decay: 4.93e-08
# Epoch 100/100
# 96/96 [==============================] - 87s 911ms/step - loss: 2.0184 - acc: 0.9999 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - val_loss: 2.8430 - val_acc: 0.7409 - val_top_5_acc: 0.9119 - val_top_10_acc: 0.9363 - lr: 9.8664e-07

# %%
def plot_history_metric(metric, f_best=np.argmax, ylim=None, yscale=None, yticks=None):
    plt.figure(figsize=(20, 10))

    values = transformer_history.history[metric]
    N_EPOCHS = len(values)
    val = 'val' in ''.join(transformer_history.history.keys())
    # Epoch Ticks
    if N_EPOCHS <= 20:
        x = np.arange(1, N_EPOCHS + 1)
    else:
        x = [1, 5] + [10 + 5 * idx for idx in range((N_EPOCHS - 10) // 5 + 1)]

    x_ticks = np.arange(1, N_EPOCHS+1)

    # Validation
    if val:
        val_values = transformer_history.history[f'val_{metric}']
        val_argmin = f_best(val_values)
        plt.plot(x_ticks, val_values, label=f'val')

    # summarize history for accuracy
    plt.plot(x_ticks, values, label=f'train')
    argmin = f_best(values)
    plt.scatter(argmin + 1, values[argmin], color='red', s=75, marker='o', label=f'train_best')
    if val:
        plt.scatter(val_argmin + 1, val_values[val_argmin], color='purple', s=75, marker='o', label=f'val_best')

    plt.title(f'Model {metric}', fontsize=24, pad=10)
    plt.ylabel(metric, fontsize=20, labelpad=10)

    if ylim:
        plt.ylim(ylim)

    if yscale is not None:
        plt.yscale(yscale)

    if yticks is not None:
        plt.yticks(yticks, fontsize=16)

    plt.xlabel('epoch', fontsize=20, labelpad=10)
    plt.tick_params(axis='x', labelsize=8)
    plt.xticks(x, fontsize=16) # set tick step to 1 and let x axis start at 1
    plt.yticks(fontsize=16)

    plt.legend(prop={'size': 10})
    plt.grid()
    plt.show()

# %%
plot_history_metric('acc', ylim=[0,1], yticks=np.arange(0.0, 1.1, 0.1))

# %%
plot_history_metric('top_5_acc', ylim=[0,1], yticks=np.arange(0.0, 1.1, 0.1))

# %%
plot_history_metric('top_10_acc', ylim=[0,1], yticks=np.arange(0.0, 1.1, 0.1))

# %%
plot_history_metric('loss', f_best=np.argmin)

# %%
# Validation Predictions
transformer_y_val_pred = transformer_model.predict({ 'frames': X_val, 'non_empty_frame_idxs': NON_EMPTY_FRAME_IDXS_VAL }, verbose=2).argmax(axis=1)
# Label
labels = [ORD2SIGN.get(i).replace(' ', '_') for i in range(NUM_CLASSES)]
# Out:
# 300/300 - 6s - 6s/epoch - 19ms/step

# %%
def print_classification_report():
    # Classification report for all signs
    classification_report = sklearn.metrics.classification_report(
            y_val,
            transformer_y_val_pred,
            target_names=labels,
            output_dict=True,
        )
    # Round Data for better readability
    classification_report = pd.DataFrame(classification_report).T
    classification_report = classification_report.round(2)
    classification_report = classification_report.astype({
            'support': np.uint16,
        })
    # Add signs
    classification_report['sign'] = [e if e in SIGN2ORD else -1 for e in classification_report.index]
    classification_report['sign_ord'] = classification_report['sign'].apply(SIGN2ORD.get).fillna(-1).astype(np.int16)
    # Sort on F1-score
    classification_report = pd.concat((
        classification_report.head(NUM_CLASSES).sort_values('f1-score', ascending=False),
        classification_report.tail(3),
    ))

    pd.options.display.max_rows = 999
    display(classification_report)

print_classification_report()
# Out:
#               precision  recall  f1-score  support          sign  sign_ord
# doll               0.98    1.00      0.99       40          doll        59
# brown              0.97    1.00      0.99       38         brown        31
# airplane           0.95    1.00      0.98       39      airplane         2
# drink              0.95    1.00      0.98       40         drink        63
# cow                0.98    0.98      0.98       42           cow        50
# horse              0.95    1.00      0.98       39         horse       119
# radio              0.95    1.00      0.97       38         radio       182
# high               0.95    1.00      0.97       37          high       117
# nose               0.95    1.00      0.97       38          nose       155
# food               0.92    1.00      0.96       37          food        87
# frog               0.97    0.95      0.96       37          frog        90
# giraffe            0.94    0.97      0.96       35       giraffe        93
# owl                0.95    0.97      0.96       39           owl       165
# please             0.93    1.00      0.96       41        please       173
# gum                0.93    1.00      0.96       40           gum       103
# moon               0.93    0.98      0.95       40          moon       146
# cry                0.91    1.00      0.95       39           cry        52
# flower             0.97    0.92      0.95       38        flower        86
# for                0.97    0.92      0.95       38           for        88
# who                0.91    1.00      0.95       40           who       239
# icecream           0.97    0.92      0.95       40      icecream       122
# mouse              0.97    0.92      0.95       40         mouse       148
# lion               0.95    0.95      0.95       40          lion       133
# uncle              0.91    0.98      0.94       40         uncle       228
# feet               0.90    0.97      0.94       39          feet        77
# eye                0.90    0.97      0.94       39           eye        72
# tiger              0.92    0.95      0.94       38         tiger       219
# because            0.93    0.95      0.94       40       because        16
# boy                0.89    0.98      0.93       41           boy        29
# shhh               0.87    1.00      0.93       40          shhh       194
# bath               0.90    0.95      0.93       40          bath        15
# cereal             0.94    0.92      0.93       37        cereal        39
# head               0.87    0.98      0.92       41          head       110
# shirt              0.90    0.95      0.92       38         shirt       195
# hungry             0.88    0.97      0.92       38        hungry       121
# water              0.85    1.00      0.92       40         water       234
# police             0.87    0.98      0.92       40        police       174
# underwear          0.85    0.98      0.91       40     underwear       229
# cute               0.97    0.85      0.91       41          cute        54
# black              1.00    0.83      0.91       41         black        24
# flag               0.88    0.95      0.91       38          flag        85
# donkey             0.85    0.98      0.91       40        donkey        60
# chocolate          0.92    0.90      0.91       40     chocolate        44
# potty              0.89    0.91      0.90       34         potty       176
# ear                1.00    0.82      0.90       45           ear        68
# orange             0.97    0.82      0.89       40        orange       162
# if                 0.90    0.88      0.89       40            if       123
# morning            0.84    0.94      0.89       34       morning       147
# rain               0.90    0.88      0.89       40          rain       183
# no                 0.86    0.90      0.88       40            no       153
# callonphone        0.88    0.88      0.88       41   callonphone        34
# pig                0.78    1.00      0.88       40           pig       171
# dad                0.92    0.85      0.88       40           dad        55
# where              0.84    0.92      0.88       39         where       237
# stuck              0.86    0.89      0.88       36         stuck       209
# brother            0.86    0.90      0.88       40       brother        30
# up                 0.81    0.95      0.87       40            up       230
# blow               0.84    0.90      0.87       40          blow        25
# fireman            0.94    0.80      0.86       40       fireman        82
# grandpa            0.82    0.90      0.86       41       grandpa       100
# TV                 0.82    0.90      0.86       40            TV         0
# yesterday          0.79    0.95      0.86       40     yesterday       245
# table              0.77    0.97      0.86       37         table       211
# man                0.82    0.90      0.86       40           man       140
# apple              1.00    0.76      0.86       37         apple         8
# toy                0.94    0.80      0.86       40           toy       226
# minemy             0.85    0.85      0.85       40        minemy       143
# shoe               0.89    0.80      0.85       41          shoe       196
# aunt               0.84    0.86      0.85       37          aunt        10
# like               0.82    0.88      0.85       42          like       132
# cowboy             0.81    0.90      0.85       39        cowboy        51
# clown              0.97    0.76      0.85       41         clown        49
# mad                0.81    0.89      0.85       38           mad       138
# wolf               0.91    0.79      0.85       38          wolf       242
# hat                0.75    0.97      0.85       31           hat       106
# time               0.78    0.94      0.85       34          time       220
# dirty              0.91    0.81      0.85       36         dirty        57
# dance              0.79    0.90      0.84       29         dance        56
# same               0.77    0.92      0.84       40          same       190
# any                0.75    0.95      0.84       41           any         7
# happy              0.75    0.95      0.84       42         happy       105
# sad                0.76    0.92      0.83       37           sad       189
# have               0.70    1.00      0.83       38          have       108
# zebra              0.74    0.95      0.83       41         zebra       248
# home               0.94    0.75      0.83       40          home       118
# down               0.79    0.87      0.83       31          down        61
# not                0.74    0.95      0.83       41           not       156
# dry                0.81    0.85      0.83       41           dry        65
# thirsty            0.77    0.90      0.83       30       thirsty       218
# store              0.79    0.87      0.83       39         store       207
# sick               1.00    0.69      0.82       39          sick       198
# old                0.88    0.78      0.82       36           old       159
# all                0.91    0.74      0.82       39           all         3
# jump               0.91    0.75      0.82       40          jump       127
# smile              0.73    0.93      0.82       41         smile       201
# yellow             0.82    0.82      0.82       39        yellow       243
# toothbrush         0.88    0.77      0.82       39    toothbrush       224
# red                0.80    0.85      0.82       39           red       185
# napkin             0.80    0.85      0.82       41        napkin       151
# see                0.70    1.00      0.82       42           see       193
# pajamas            0.88    0.76      0.81       37       pajamas       166
# tomorrow           0.93    0.71      0.81       35      tomorrow       221
# talk               0.75    0.85      0.80       39          talk       212
# bee                0.73    0.88      0.80       40           bee        19
# bed                0.74    0.84      0.79       38           bed        17
# scissors           0.71    0.88      0.79       40      scissors       192
# weus               0.69    0.92      0.79       40          weus       236
# snow               0.90    0.70      0.79       40          snow       203
# bird               0.66    1.00      0.79       38          bird        23
# cut                0.81    0.78      0.79       37           cut        53
# tree               0.84    0.75      0.79       36          tree       227
# nuts               0.78    0.79      0.78       39          nuts       158
# dryer              0.93    0.68      0.78       40         dryer        66
# stairs             0.88    0.68      0.77       41        stairs       204
# beside             0.73    0.83      0.77       29        beside        21
# elephant           0.83    0.72      0.77       40      elephant        69
# bye                0.63    0.98      0.77       41           bye        33
# frenchfries        0.62    1.00      0.77       41   frenchfries        89
# fine               0.92    0.67      0.77       33          fine        79
# better             0.76    0.79      0.77       39        better        22
# on                 0.76    0.76      0.76       41            on       160
# make               0.73    0.80      0.76       40          make       139
# green              0.74    0.78      0.76       36         green       102
# hot                0.96    0.62      0.76       40           hot       120
# why                0.93    0.64      0.76       39           why       240
# night              0.78    0.75      0.76       28         night       152
# stay               0.84    0.69      0.76       39          stay       205
# story              0.89    0.64      0.75       39         story       208
# cheek              0.96    0.61      0.75       41         cheek        41
# will               0.72    0.76      0.74       37          will       241
# chair              0.75    0.73      0.74       37         chair        40
# hen                0.82    0.67      0.74       42           hen       114
# hesheit            0.59    0.98      0.74       40       hesheit       115
# now                0.64    0.88      0.74       32           now       157
# bug                0.63    0.88      0.73       41           bug        32
# pretend            0.65    0.82      0.73       40       pretend       177
# penny              0.70    0.77      0.73       39         penny       169
# yourself           0.64    0.84      0.73       38      yourself       246
# mitten             0.81    0.67      0.73       39        mitten       144
# think              0.78    0.68      0.72       37         think       217
# read               0.76    0.69      0.72       36          read       184
# quiet              0.74    0.71      0.72       41         quiet       181
# zipper             0.87    0.62      0.72       21        zipper       249
# girl               1.00    0.57      0.72       37          girl        94
# animal             0.77    0.67      0.72       36        animal         5
# boat               0.65    0.80      0.72       35          boat        27
# duck               0.64    0.81      0.72       42          duck        67
# white              0.83    0.62      0.71       40         white       238
# later              0.68    0.74      0.71       38         later       131
# pencil             0.66    0.74      0.70       42        pencil       168
# bad                0.80    0.62      0.70       39           bad        13
# car                0.85    0.59      0.70       39           car        36
# cloud              0.67    0.71      0.69       41         cloud        48
# finish             0.66    0.72      0.69       40        finish        81
# hear               0.55    0.90      0.69       40          hear       111
# bedroom            0.75    0.64      0.69       42       bedroom        18
# fast               0.63    0.74      0.68       35          fast        76
# fall               0.91    0.54      0.68       37          fall        74
# empty              0.68    0.69      0.68       39         empty        70
# chin               0.85    0.56      0.68       39          chin        43
# closet             0.88    0.55      0.68       40        closet        47
# can                0.63    0.75      0.68       36           can        35
# blue               0.85    0.56      0.68       39          blue        26
# look               0.95    0.53      0.68       38          look       136
# loud               0.82    0.57      0.68       40          loud       137
# hair               0.67    0.67      0.67       39          hair       104
# sleepy             0.67    0.67      0.67       42        sleepy       200
# shower             0.67    0.67      0.67       36        shower       197
# lips               0.53    0.92      0.67       40          lips       134
# person             0.61    0.73      0.67       15        person       170
# alligator          0.88    0.54      0.67       41     alligator         4
# puzzle             0.71    0.63      0.67       35        puzzle       180
# refrigerator       0.83    0.54      0.66       35  refrigerator       186
# jacket             0.73    0.60      0.66       40        jacket       125
# open               0.54    0.84      0.66       32          open       161
# fish               0.56    0.79      0.65       38          fish        84
# pool               0.81    0.54      0.65       39          pool       175
# taste              0.52    0.87      0.65       38         taste       213
# into               0.63    0.68      0.65       40          into       124
# hello              0.70    0.61      0.65       38         hello       113
# backyard           0.74    0.56      0.64       41      backyard        12
# mom                0.52    0.84      0.64       38           mom       145
# snack              0.73    0.56      0.64       39         snack       202
# thankyou           0.49    0.91      0.64       35      thankyou       214
# kiss               0.61    0.68      0.64       40          kiss       128
# carrot             0.95    0.48      0.63       40        carrot        37
# say                0.48    0.94      0.63       35           say       191
# another            0.69    0.58      0.63       31       another         6
# farm               0.68    0.59      0.63       39          farm        75
# touch              0.81    0.51      0.63       41         touch       225
# arm                0.76    0.54      0.63       41           arm         9
# milk               0.55    0.74      0.63       38          milk       142
# gift               0.54    0.76      0.63       38          gift        92
# first              0.68    0.57      0.62       40         first        83
# tooth              0.59    0.66      0.62       35         tooth       223
# haveto             0.60    0.64      0.62       39        haveto       109
# ride               0.81    0.49      0.61       35          ride       187
# lamp               0.77    0.50      0.61       40          lamp       130
# pizza              0.67    0.57      0.61       46         pizza       172
# yes                0.50    0.74      0.60       39           yes       244
# book               0.53    0.69      0.60       36          book        28
# listen             0.74    0.50      0.60       40        listen       135
# tongue             0.53    0.66      0.59       41        tongue       222
# child              0.66    0.54      0.59       39         child        42
# wake               0.48    0.78      0.59       40          wake       233
# drop               1.00    0.42      0.59       31          drop        64
# hide               0.78    0.47      0.59       38          hide       116
# sticky             0.48    0.76      0.59       33        sticky       206
# face               0.45    0.87      0.59       38          face        73
# hate               0.56    0.63      0.59       38          hate       107
# garbage            0.78    0.47      0.59       38       garbage        91
# before             0.49    0.71      0.58       35        before        20
# clean              0.55    0.61      0.58       36         clean        45
# wait               0.46    0.77      0.58       31          wait       232
# that               0.60    0.54      0.57       39          that       215
# balloon            0.61    0.55      0.57       42       balloon        14
# noisy              0.84    0.42      0.56       38         noisy       154
# wet                0.61    0.50      0.55       46           wet       235
# dog                0.58    0.50      0.54       36           dog        58
# finger             0.68    0.45      0.54       38        finger        80
# yucky              0.48    0.59      0.53       34         yucky       247
# puppy              0.58    0.48      0.53       44         puppy       179
# drawer             0.48    0.61      0.53       38        drawer        62
# grass              0.53    0.53      0.53       38         grass       101
# sun                0.54    0.48      0.51       40           sun       210
# vacuum             0.47    0.57      0.51       35        vacuum       231
# helicopter         0.79    0.37      0.50       41    helicopter       112
# jeans              0.88    0.35      0.50       40         jeans       126
# every              0.65    0.41      0.50       32         every        71
# room               0.50    0.50      0.50       40          room       188
# close              0.64    0.40      0.49       45         close        46
# sleep              0.38    0.68      0.49       38         sleep       199
# grandma            0.46    0.54      0.49       39       grandma        99
# pretty             0.55    0.42      0.48       38        pretty       178
# pen                0.54    0.34      0.42       41           pen       167
# goose              0.59    0.31      0.41       42         goose        98
# owie               0.65    0.30      0.41       37          owie       164
# there              0.56    0.30      0.39       30         there       216
# find               0.31    0.50      0.38       40          find        78
# kitty              0.38    0.38      0.38       42         kitty       129
# outside            0.83    0.24      0.37       42       outside       163
# glasswindow        0.39    0.31      0.35       35   glasswindow        96
# many               0.26    0.41      0.32       29          many       141
# nap                0.88    0.16      0.26       45           nap       150
# go                 0.33    0.21      0.26       33            go        97
# awake              0.43    0.15      0.23       39         awake        11
# give               0.42    0.15      0.22       33          give        95
# after              0.32    0.17      0.22       41         after         1
# mouth              0.44    0.10      0.16       40         mouth       149
# cat                0.19    0.08      0.11       38           cat        38
# accuracy           0.74    0.74      0.74        0            -1        -1
# macro avg          0.76    0.74      0.73     9592            -1        -1
# weighted avg       0.76    0.74      0.73     9592            -1        -1

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred_probs = transformer_model.predict({'frames' : X_test,'non_empty_frame_idxs': NON_EMPTY_FRAME_IDXS_TEST }, verbose=2).argmax(axis=1)
accuracy = accuracy_score(y_test, y_pred_probs)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 398/398 - 8s - 8s/epoch - 19ms/step
# Test Accuracy: 0.5800

# %%
lstm_y_pred_probs = lstm_model.predict({'frames' : X_test,'non_empty_frame_idxs': NON_EMPTY_FRAME_IDXS_TEST }, verbose=2).argmax(axis=1)
accuracy = accuracy_score(y_test, lstm_y_pred_probs)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 398/398 - 8s - 8s/epoch - 19ms/step
# Test Accuracy: 0.5031

# %%
lstm_model.save('full_lstm_model')

# %%
class DenseBlock(layers.Layer):
    def __init__(self, units, drop):
        super().__init__()
        self.dense = layers.Dense(units)
        self.norm = layers.LayerNormalization()
        self.relu = layers.Activation("gelu")
        self.drop = layers.Dropout(drop)

    def call(self, x):
        x = self.dense(x)
        x = self.norm(x)
        x = self.relu(x)
        x = self.drop(x)
        return x

class ClassifierLSTM(layers.Layer):
    def __init__(self, lstm_units, drop):
        super().__init__()
        self.dropout = layers.Dropout(drop)
        self.pool2d = layers.AveragePooling2D(pool_size=(4, 1))
        self.reshape = layers.Reshape((-1, 64))
        self.lstm = layers.LSTM(unaits=lstm_units, return_sequences=True)
        self.pool1d = layers.AveragePooling1D(pool_size=4)
        self.flat = layers.Flatten()
        self.outputs = layers.Dense(250, activation="softmax", name="predictions")

    def call(self, x):
        x = self.pool2d(x)
        x = self.reshape(x)
        x = self.lstm(x)
        x = self.dropout(x)
        x = self.pool1d(x)
        x = self.flat(x)
        outputs = self.outputs(x)
        return outputs

class ClassifierConvLSTM1D(layers.Layer):
    def __init__(self, lstm_units, drop):
        super().__init__()
        self.expand_dim = layers.Reshape((64, 64, 1))
        self.pool2d = layers.AveragePooling2D(pool_size=(6, 1))
        self.conv_lstm1D = layers.ConvLSTM1D(filters=lstm_units, kernel_size=1)
        self.dropout = layers.Dropout(drop)
        self.flat = layers.Flatten()
        self.outputs = layers.Dense(250, activation="softmax", name="predictions")

    def call(self, x):
        x = self.expand_dim(x)
        x = self.pool2d(x)
        x = self.conv_lstm1D(x)
        x = self.dropout(x)
        x = self.flat(x)
        outputs = self.outputs(x)
        return outputs

# %%
#LSTM_model
def get_lstm_model(encoder_units=[512, 64], drop=0.5, lstm_units=250):
    # Inputs
    frames = tf.keras.layers.Input([INPUT_SIZE, n_cols, N_DIMS], dtype=tf.float32, name='frames')
    non_empty_frame_idxs = tf.keras.layers.Input([INPUT_SIZE], dtype=tf.float32, name='non_empty_frame_idxs')

    # Padding Mask
    mask0 = tf.cast(tf.math.not_equal(non_empty_frame_idxs, -1), tf.float32)
    mask0 = tf.expand_dims(mask0, axis=2)
    # Random Frame Masking
    mask = tf.where(
        (tf.random.uniform(tf.shape(mask0)) > 0.25) & tf.math.not_equal(mask0, 0.0),
        1.0,
        0.0,
    )
    # Correct Samples Which are all masked now...
    mask = tf.where(
        tf.math.equal(tf.reduce_sum(mask, axis=[1,2], keepdims=True), 0.0),
        mask0,
        mask,
    )

    x = tf.slice(frames, [0,0,0,0], [-1,INPUT_SIZE, n_cols, 2])

    # LIPS
    lips = tf.slice(x, [0,0,LIPS_START,0], [-1,INPUT_SIZE, 40, 2])
    lips = tf.where(
            tf.math.equal(lips, 0.0),
            0.0,
            (lips - LIP_MEAN) / LIP_STD,
        )

    # LEFT HAND
    left_hand = tf.slice(x, [0,0,40,0], [-1,INPUT_SIZE, 21, 2])
    left_hand = tf.where(
            tf.math.equal(left_hand, 0.0),
            0.0,
            (left_hand - LEFT_HANDS_MEAN) / LEFT_HANDS_STD,
        )

    # POSE
    pose = tf.slice(x, [0,0,61,0], [-1,INPUT_SIZE, 5, 2])
    pose = tf.where(
            tf.math.equal(pose, 0.0),
            0.0,
            (pose - POSE_MEAN) / POSE_STD,
        )

    # Flatten
    lips = tf.reshape(lips, [-1, INPUT_SIZE, 40*2])
    left_hand = tf.reshape(left_hand, [-1, INPUT_SIZE, 21*2])
    pose = tf.reshape(pose, [-1, INPUT_SIZE, 5*2])
    print(pose.shape)
    # Embedding
    x = Embedding()(lips, left_hand, pose, non_empty_frame_idxs)

    # Process through DenseBlock and Classifier
    for units in encoder_units:
        x = DenseBlock(units, drop)(x)

    outputs = ClassifierConvLSTM1D(lstm_units, drop)(x)

    model = tf.keras.Model(inputs=[frames, non_empty_frame_idxs], outputs=outputs)
    optimizer = tfa.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-5, clipnorm=1.0)
    # TopK Metrics
    metrics = [
        tf.keras.metrics.SparseCategoricalAccuracy(name='acc'),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name='top_5_acc'),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=10, name='top_10_acc'),
    ]
    model.compile(
        loss=scce_with_ls,
        optimizer=optimizer,
        metrics=metrics,
    )
    return model
lstm_model = get_lstm_model()
# Out:
# (None, 64, 10)

# %%
# Custom callback to update weight decay with learning rate
class WeightDecayCallback(tf.keras.callbacks.Callback):
    def __init__(self, wd_ratio=WD_RATIO):
        self.step_counter = 0
        self.wd_ratio = wd_ratio

    def on_epoch_begin(self, epoch, logs=None):
        lstm_model.optimizer.weight_decay = lstm_model.optimizer.learning_rate * self.wd_ratio
        print(f'learning rate: {lstm_model.optimizer.learning_rate.numpy():.2e}, weight decay: {lstm_model.optimizer.weight_decay.numpy():.2e}')

# %%
# Actual Training
lstm_history = lstm_model.fit(
        x=get_train_batch_all_signs(X_train, y_train, NON_EMPTY_FRAME_IDXS_TRAIN),
        steps_per_epoch=len(X_train) // (NUM_CLASSES * BATCH_ALL_SIGNS_N),
        epochs=N_EPOCHS,
        # Only used for validation data since training data is a generator
        batch_size=BATCH_SIZE,
        validation_data=validation_data,
        callbacks=[
            lr_callback,
            WeightDecayCallback(),
            increase_stopping,
        ],
        verbose = VERBOSE,
    )
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 8.881784197001253e-19.
# learning rate: 8.88e-19, weight decay: 4.44e-20
# Epoch 1/100
# 96/96 [==============================] - 94s 914ms/step - loss: 5.5216 - acc: 0.0041 - top_5_acc: 0.0197 - top_10_acc: 0.0394 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 8.8818e-19
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.7763568394002505e-18.
# learning rate: 1.78e-18, weight decay: 8.88e-20
# Epoch 2/100
# 96/96 [==============================] - 88s 913ms/step - loss: 5.5215 - acc: 0.0035 - top_5_acc: 0.0196 - top_10_acc: 0.0389 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 1.7764e-18
#
# Epoch 3: LearningRateScheduler setting learning rate to 3.552713678800501e-18.
# learning rate: 3.55e-18, weight decay: 1.78e-19
# Epoch 3/100
# 96/96 [==============================] - 88s 920ms/step - loss: 5.5215 - acc: 0.0041 - top_5_acc: 0.0203 - top_10_acc: 0.0405 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 3.5527e-18
#
# Epoch 4: LearningRateScheduler setting learning rate to 7.105427357601002e-18.
# learning rate: 7.11e-18, weight decay: 3.55e-19
# Epoch 4/100
# 96/96 [==============================] - 89s 926ms/step - loss: 5.5216 - acc: 0.0041 - top_5_acc: 0.0198 - top_10_acc: 0.0401 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 7.1054e-18
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.4210854715202004e-17.
# learning rate: 1.42e-17, weight decay: 7.11e-19
# Epoch 5/100
# 96/96 [==============================] - 88s 919ms/step - loss: 5.5216 - acc: 0.0038 - top_5_acc: 0.0190 - top_10_acc: 0.0385 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 1.4211e-17
#
# Epoch 6: LearningRateScheduler setting learning rate to 2.842170943040401e-17.
# learning rate: 2.84e-17, weight decay: 1.42e-18
# Epoch 6/100
# 96/96 [==============================] - 88s 919ms/step - loss: 5.5216 - acc: 0.0040 - top_5_acc: 0.0188 - top_10_acc: 0.0382 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 2.8422e-17
#
# Epoch 7: LearningRateScheduler setting learning rate to 5.684341886080802e-17.
# learning rate: 5.68e-17, weight decay: 2.84e-18
# Epoch 7/100
# 96/96 [==============================] - 89s 931ms/step - loss: 5.5216 - acc: 0.0039 - top_5_acc: 0.0193 - top_10_acc: 0.0392 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 5.6843e-17
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.1368683772161603e-16.
# learning rate: 1.14e-16, weight decay: 5.68e-18
# Epoch 8/100
# 96/96 [==============================] - 88s 919ms/step - loss: 5.5216 - acc: 0.0043 - top_5_acc: 0.0199 - top_10_acc: 0.0408 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 1.1369e-16
#
# Epoch 9: LearningRateScheduler setting learning rate to 2.2737367544323206e-16.
# learning rate: 2.27e-16, weight decay: 1.14e-17
# Epoch 9/100
# 96/96 [==============================] - 89s 931ms/step - loss: 5.5216 - acc: 0.0039 - top_5_acc: 0.0200 - top_10_acc: 0.0393 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 2.2737e-16
#
# Epoch 10: LearningRateScheduler setting learning rate to 4.547473508864641e-16.
# learning rate: 4.55e-16, weight decay: 2.27e-17
# Epoch 10/100
# 96/96 [==============================] - 89s 929ms/step - loss: 5.5216 - acc: 0.0038 - top_5_acc: 0.0198 - top_10_acc: 0.0394 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 4.5475e-16
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.094947017729283e-16.
# learning rate: 9.09e-16, weight decay: 4.55e-17
# Epoch 11/100
# 96/96 [==============================] - 89s 929ms/step - loss: 5.5215 - acc: 0.0038 - top_5_acc: 0.0196 - top_10_acc: 0.0390 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 9.0949e-16
#
# Epoch 12: LearningRateScheduler setting learning rate to 1.8189894035458565e-15.
# learning rate: 1.82e-15, weight decay: 9.09e-17
# Epoch 12/100
# 96/96 [==============================] - 88s 919ms/step - loss: 5.5215 - acc: 0.0038 - top_5_acc: 0.0193 - top_10_acc: 0.0392 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 1.8190e-15
#
# Epoch 13: LearningRateScheduler setting learning rate to 3.637978807091713e-15.
# learning rate: 3.64e-15, weight decay: 1.82e-16
# Epoch 13/100
# 96/96 [==============================] - 89s 931ms/step - loss: 5.5216 - acc: 0.0043 - top_5_acc: 0.0205 - top_10_acc: 0.0402 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 3.6380e-15
#
# Epoch 14: LearningRateScheduler setting learning rate to 7.275957614183426e-15.
# learning rate: 7.28e-15, weight decay: 3.64e-16
# Epoch 14/100
# 96/96 [==============================] - 88s 918ms/step - loss: 5.5216 - acc: 0.0043 - top_5_acc: 0.0206 - top_10_acc: 0.0404 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 7.2760e-15
#
# Epoch 15: LearningRateScheduler setting learning rate to 1.4551915228366852e-14.
# learning rate: 1.46e-14, weight decay: 7.28e-16
# Epoch 15/100
# 96/96 [==============================] - 90s 933ms/step - loss: 5.5215 - acc: 0.0042 - top_5_acc: 0.0208 - top_10_acc: 0.0406 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 1.4552e-14
#
# Epoch 16: LearningRateScheduler setting learning rate to 2.9103830456733704e-14.
# learning rate: 2.91e-14, weight decay: 1.46e-15
# Epoch 16/100
# 96/96 [==============================] - 90s 934ms/step - loss: 5.5216 - acc: 0.0040 - top_5_acc: 0.0200 - top_10_acc: 0.0387 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 2.9104e-14
#
# Epoch 17: LearningRateScheduler setting learning rate to 5.820766091346741e-14.
# learning rate: 5.82e-14, weight decay: 2.91e-15
# Epoch 17/100
# 96/96 [==============================] - 90s 934ms/step - loss: 5.5216 - acc: 0.0041 - top_5_acc: 0.0202 - top_10_acc: 0.0398 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 5.8208e-14
#
# Epoch 18: LearningRateScheduler setting learning rate to 1.1641532182693482e-13.
# learning rate: 1.16e-13, weight decay: 5.82e-15
# Epoch 18/100
# 96/96 [==============================] - 90s 935ms/step - loss: 5.5216 - acc: 0.0042 - top_5_acc: 0.0196 - top_10_acc: 0.0393 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 1.1642e-13
#
# Epoch 19: LearningRateScheduler setting learning rate to 2.3283064365386963e-13.
# learning rate: 2.33e-13, weight decay: 1.16e-14
# Epoch 19/100
# 96/96 [==============================] - 90s 936ms/step - loss: 5.5216 - acc: 0.0040 - top_5_acc: 0.0190 - top_10_acc: 0.0386 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 2.3283e-13
#
# Epoch 20: LearningRateScheduler setting learning rate to 4.656612873077393e-13.
# learning rate: 4.66e-13, weight decay: 2.33e-14
# Epoch 20/100
# 96/96 [==============================] - 90s 936ms/step - loss: 5.5216 - acc: 0.0039 - top_5_acc: 0.0192 - top_10_acc: 0.0377 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 4.6566e-13
#
# Epoch 21: LearningRateScheduler setting learning rate to 9.313225746154785e-13.
# learning rate: 9.31e-13, weight decay: 4.66e-14
# Epoch 21/100
# 96/96 [==============================] - 90s 935ms/step - loss: 5.5216 - acc: 0.0038 - top_5_acc: 0.0197 - top_10_acc: 0.0390 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 9.3132e-13
#
# Epoch 22: LearningRateScheduler setting learning rate to 1.862645149230957e-12.
# learning rate: 1.86e-12, weight decay: 9.31e-14
# Epoch 22/100
# 96/96 [==============================] - 90s 936ms/step - loss: 5.5216 - acc: 0.0041 - top_5_acc: 0.0197 - top_10_acc: 0.0396 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 1.8626e-12
#
# Epoch 23: LearningRateScheduler setting learning rate to 3.725290298461914e-12.
# learning rate: 3.73e-12, weight decay: 1.86e-13
# Epoch 23/100
# 96/96 [==============================] - 90s 935ms/step - loss: 5.5216 - acc: 0.0041 - top_5_acc: 0.0195 - top_10_acc: 0.0397 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 3.7253e-12
#
# Epoch 24: LearningRateScheduler setting learning rate to 7.450580596923828e-12.
# learning rate: 7.45e-12, weight decay: 3.73e-13
# Epoch 24/100
# 96/96 [==============================] - 90s 934ms/step - loss: 5.5216 - acc: 0.0040 - top_5_acc: 0.0203 - top_10_acc: 0.0393 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 7.4506e-12
#
# Epoch 25: LearningRateScheduler setting learning rate to 1.4901161193847657e-11.
# learning rate: 1.49e-11, weight decay: 7.45e-13
# Epoch 25/100
# 96/96 [==============================] - 89s 925ms/step - loss: 5.5216 - acc: 0.0040 - top_5_acc: 0.0208 - top_10_acc: 0.0409 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 1.4901e-11
#
# Epoch 26: LearningRateScheduler setting learning rate to 2.980232238769531e-11.
# learning rate: 2.98e-11, weight decay: 1.49e-12
# Epoch 26/100
# 96/96 [==============================] - 90s 935ms/step - loss: 5.5216 - acc: 0.0043 - top_5_acc: 0.0207 - top_10_acc: 0.0400 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 2.9802e-11
#
# Epoch 27: LearningRateScheduler setting learning rate to 5.960464477539063e-11.
# learning rate: 5.96e-11, weight decay: 2.98e-12
# Epoch 27/100
# 96/96 [==============================] - 89s 926ms/step - loss: 5.5215 - acc: 0.0041 - top_5_acc: 0.0199 - top_10_acc: 0.0393 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 5.9605e-11
#
# Epoch 28: LearningRateScheduler setting learning rate to 1.1920928955078125e-10.
# learning rate: 1.19e-10, weight decay: 5.96e-12
# Epoch 28/100
# 96/96 [==============================] - 89s 926ms/step - loss: 5.5215 - acc: 0.0040 - top_5_acc: 0.0197 - top_10_acc: 0.0394 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 1.1921e-10
#
# Epoch 29: LearningRateScheduler setting learning rate to 2.384185791015625e-10.
# learning rate: 2.38e-10, weight decay: 1.19e-11
# Epoch 29/100
# 96/96 [==============================] - 90s 934ms/step - loss: 5.5216 - acc: 0.0039 - top_5_acc: 0.0192 - top_10_acc: 0.0388 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0376 - lr: 2.3842e-10
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.76837158203125e-10.
# learning rate: 4.77e-10, weight decay: 2.38e-11
# Epoch 30/100
# 96/96 [==============================] - 89s 931ms/step - loss: 5.5216 - acc: 0.0036 - top_5_acc: 0.0191 - top_10_acc: 0.0385 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0209 - val_top_10_acc: 0.0375 - lr: 4.7684e-10
#
# Epoch 31: LearningRateScheduler setting learning rate to 9.5367431640625e-10.
# learning rate: 9.54e-10, weight decay: 4.77e-11
# Epoch 31/100
# 96/96 [==============================] - 88s 920ms/step - loss: 5.5216 - acc: 0.0033 - top_5_acc: 0.0194 - top_10_acc: 0.0392 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0210 - val_top_10_acc: 0.0375 - lr: 9.5367e-10
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.9073486328125e-09.
# learning rate: 1.91e-09, weight decay: 9.54e-11
# Epoch 32/100
# 96/96 [==============================] - 88s 919ms/step - loss: 5.5216 - acc: 0.0042 - top_5_acc: 0.0204 - top_10_acc: 0.0403 - val_loss: 5.5215 - val_acc: 0.0041 - val_top_5_acc: 0.0211 - val_top_10_acc: 0.0376 - lr: 1.9073e-09
#
# Epoch 33: LearningRateScheduler setting learning rate to 3.814697265625e-09.
# learning rate: 3.81e-09, weight decay: 1.91e-10
# Epoch 33/100
# 96/96 [==============================] - 89s 931ms/step - loss: 5.5216 - acc: 0.0040 - top_5_acc: 0.0198 - top_10_acc: 0.0401 - val_loss: 5.5215 - val_acc: 0.0040 - val_top_5_acc: 0.0210 - val_top_10_acc: 0.0376 - lr: 3.8147e-09
#
# Epoch 34: LearningRateScheduler setting learning rate to 7.62939453125e-09.
# learning rate: 7.63e-09, weight decay: 3.81e-10
# Epoch 34/100
# 96/96 [==============================] - 89s 929ms/step - loss: 5.5215 - acc: 0.0041 - top_5_acc: 0.0197 - top_10_acc: 0.0391 - val_loss: 5.5215 - val_acc: 0.0042 - val_top_5_acc: 0.0213 - val_top_10_acc: 0.0375 - lr: 7.6294e-09
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.52587890625e-08.
# learning rate: 1.53e-08, weight decay: 7.63e-10
# Epoch 35/100
# 96/96 [==============================] - 89s 928ms/step - loss: 5.5215 - acc: 0.0041 - top_5_acc: 0.0201 - top_10_acc: 0.0394 - val_loss: 5.5215 - val_acc: 0.0046 - val_top_5_acc: 0.0206 - val_top_10_acc: 0.0379 - lr: 1.5259e-08
#
# Epoch 36: LearningRateScheduler setting learning rate to 3.0517578125e-08.
# learning rate: 3.05e-08, weight decay: 1.53e-09
# Epoch 36/100
# 96/96 [==============================] - 89s 931ms/step - loss: 5.5216 - acc: 0.0042 - top_5_acc: 0.0202 - top_10_acc: 0.0397 - val_loss: 5.5215 - val_acc: 0.0050 - val_top_5_acc: 0.0216 - val_top_10_acc: 0.0368 - lr: 3.0518e-08
#
# Epoch 37: LearningRateScheduler setting learning rate to 6.103515625e-08.
# learning rate: 6.10e-08, weight decay: 3.05e-09
# Epoch 37/100
# 96/96 [==============================] - 89s 930ms/step - loss: 5.5216 - acc: 0.0041 - top_5_acc: 0.0210 - top_10_acc: 0.0406 - val_loss: 5.5215 - val_acc: 0.0051 - val_top_5_acc: 0.0221 - val_top_10_acc: 0.0376 - lr: 6.1035e-08
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.220703125e-07.
# learning rate: 1.22e-07, weight decay: 6.10e-09
# Epoch 38/100
# 96/96 [==============================] - 88s 919ms/step - loss: 5.5215 - acc: 0.0040 - top_5_acc: 0.0204 - top_10_acc: 0.0407 - val_loss: 5.5215 - val_acc: 0.0042 - val_top_5_acc: 0.0210 - val_top_10_acc: 0.0383 - lr: 1.2207e-07
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.44140625e-07.
# learning rate: 2.44e-07, weight decay: 1.22e-08
# Epoch 39/100
# 96/96 [==============================] - 89s 929ms/step - loss: 5.5215 - acc: 0.0042 - top_5_acc: 0.0203 - top_10_acc: 0.0414 - val_loss: 5.5214 - val_acc: 0.0042 - val_top_5_acc: 0.0215 - val_top_10_acc: 0.0383 - lr: 2.4414e-07
#
# Epoch 40: LearningRateScheduler setting learning rate to 4.8828125e-07.
# learning rate: 4.88e-07, weight decay: 2.44e-08
# Epoch 40/100
# 96/96 [==============================] - 89s 929ms/step - loss: 5.5214 - acc: 0.0040 - top_5_acc: 0.0216 - top_10_acc: 0.0432 - val_loss: 5.5214 - val_acc: 0.0062 - val_top_5_acc: 0.0266 - val_top_10_acc: 0.0469 - lr: 4.8828e-07
#
# Epoch 41: LearningRateScheduler setting learning rate to 9.765625e-07.
# learning rate: 9.77e-07, weight decay: 4.88e-08
# Epoch 41/100
# 96/96 [==============================] - 89s 932ms/step - loss: 5.5211 - acc: 0.0046 - top_5_acc: 0.0217 - top_10_acc: 0.0437 - val_loss: 5.5213 - val_acc: 0.0080 - val_top_5_acc: 0.0273 - val_top_10_acc: 0.0464 - lr: 9.7656e-07
#
# Epoch 42: LearningRateScheduler setting learning rate to 1.953125e-06.
# learning rate: 1.95e-06, weight decay: 9.77e-08
# Epoch 42/100
# 96/96 [==============================] - 89s 932ms/step - loss: 5.5208 - acc: 0.0048 - top_5_acc: 0.0239 - top_10_acc: 0.0455 - val_loss: 5.5212 - val_acc: 0.0045 - val_top_5_acc: 0.0266 - val_top_10_acc: 0.0488 - lr: 1.9531e-06
#
# Epoch 43: LearningRateScheduler setting learning rate to 3.90625e-06.
# learning rate: 3.91e-06, weight decay: 1.95e-07
# Epoch 43/100
# 96/96 [==============================] - 89s 930ms/step - loss: 5.5199 - acc: 0.0052 - top_5_acc: 0.0251 - top_10_acc: 0.0498 - val_loss: 5.5209 - val_acc: 0.0049 - val_top_5_acc: 0.0224 - val_top_10_acc: 0.0447 - lr: 3.9063e-06
#
# Epoch 44: LearningRateScheduler setting learning rate to 7.8125e-06.
# learning rate: 7.81e-06, weight decay: 3.91e-07
# Epoch 44/100
# 96/96 [==============================] - 88s 922ms/step - loss: 5.5156 - acc: 0.0060 - top_5_acc: 0.0292 - top_10_acc: 0.0556 - val_loss: 5.5175 - val_acc: 0.0033 - val_top_5_acc: 0.0213 - val_top_10_acc: 0.0412 - lr: 7.8125e-06
#
# Epoch 45: LearningRateScheduler setting learning rate to 1.5625e-05.
# learning rate: 1.56e-05, weight decay: 7.81e-07
# Epoch 45/100
# 96/96 [==============================] - 89s 932ms/step - loss: 5.3855 - acc: 0.0189 - top_5_acc: 0.0771 - top_10_acc: 0.1356 - val_loss: 5.0224 - val_acc: 0.0800 - val_top_5_acc: 0.2609 - val_top_10_acc: 0.3944 - lr: 1.5625e-05
#
# Epoch 46: LearningRateScheduler setting learning rate to 3.125e-05.
# learning rate: 3.13e-05, weight decay: 1.56e-06
# Epoch 46/100
# 96/96 [==============================] - 89s 929ms/step - loss: 4.6113 - acc: 0.1678 - top_5_acc: 0.4187 - top_10_acc: 0.5525 - val_loss: 4.1365 - val_acc: 0.2903 - val_top_5_acc: 0.6290 - val_top_10_acc: 0.7526 - lr: 3.1250e-05
#
# Epoch 47: LearningRateScheduler setting learning rate to 6.25e-05.
# learning rate: 6.25e-05, weight decay: 3.13e-06
# Epoch 47/100
# 96/96 [==============================] - 88s 918ms/step - loss: 4.1839 - acc: 0.3005 - top_5_acc: 0.5922 - top_10_acc: 0.7037 - val_loss: 3.7880 - val_acc: 0.4233 - val_top_5_acc: 0.7366 - val_top_10_acc: 0.8358 - lr: 6.2500e-05
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.000125.
# learning rate: 1.25e-04, weight decay: 6.25e-06
# Epoch 48/100
# 96/96 [==============================] - 89s 930ms/step - loss: 3.9627 - acc: 0.3710 - top_5_acc: 0.6589 - top_10_acc: 0.7543 - val_loss: 3.6372 - val_acc: 0.4523 - val_top_5_acc: 0.7739 - val_top_10_acc: 0.8581 - lr: 1.2500e-04
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.00025.
# learning rate: 2.50e-04, weight decay: 1.25e-05
# Epoch 49/100
# 96/96 [==============================] - 89s 930ms/step - loss: 3.7356 - acc: 0.4410 - top_5_acc: 0.7222 - top_10_acc: 0.8030 - val_loss: 3.4424 - val_acc: 0.5200 - val_top_5_acc: 0.8112 - val_top_10_acc: 0.8858 - lr: 2.5000e-04
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0005.
# learning rate: 5.00e-04, weight decay: 2.50e-05
# Epoch 50/100
# 96/96 [==============================] - 89s 931ms/step - loss: 3.5962 - acc: 0.4850 - top_5_acc: 0.7540 - top_10_acc: 0.8265 - val_loss: 3.3761 - val_acc: 0.5347 - val_top_5_acc: 0.8268 - val_top_10_acc: 0.8961 - lr: 5.0000e-04
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.001.
# learning rate: 1.00e-03, weight decay: 5.00e-05
# Epoch 51/100
# 96/96 [==============================] - 88s 922ms/step - loss: 3.5277 - acc: 0.5060 - top_5_acc: 0.7702 - top_10_acc: 0.8399 - val_loss: 3.4025 - val_acc: 0.5097 - val_top_5_acc: 0.8188 - val_top_10_acc: 0.8923 - lr: 0.0010
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.0009990133642141358.
# learning rate: 9.99e-04, weight decay: 5.00e-05
# Epoch 52/100
# 96/96 [==============================] - 89s 933ms/step - loss: 3.3915 - acc: 0.5533 - top_5_acc: 0.8032 - top_10_acc: 0.8620 - val_loss: 3.2652 - val_acc: 0.5648 - val_top_5_acc: 0.8453 - val_top_10_acc: 0.9096 - lr: 9.9901e-04
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.000996057350657239.
# learning rate: 9.96e-04, weight decay: 4.98e-05
# Epoch 53/100
# 96/96 [==============================] - 89s 931ms/step - loss: 3.3023 - acc: 0.5879 - top_5_acc: 0.8210 - top_10_acc: 0.8742 - val_loss: 3.1950 - val_acc: 0.5910 - val_top_5_acc: 0.8653 - val_top_10_acc: 0.9206 - lr: 9.9606e-04
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0009911436253643444.
# learning rate: 9.91e-04, weight decay: 4.96e-05
# Epoch 54/100
# 96/96 [==============================] - 88s 921ms/step - loss: 3.2417 - acc: 0.6086 - top_5_acc: 0.8322 - top_10_acc: 0.8834 - val_loss: 3.1357 - val_acc: 0.6196 - val_top_5_acc: 0.8783 - val_top_10_acc: 0.9306 - lr: 9.9114e-04
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.0009842915805643156.
# learning rate: 9.84e-04, weight decay: 4.92e-05
# Epoch 55/100
# 96/96 [==============================] - 89s 932ms/step - loss: 3.1980 - acc: 0.6244 - top_5_acc: 0.8414 - top_10_acc: 0.8886 - val_loss: 3.1116 - val_acc: 0.6263 - val_top_5_acc: 0.8764 - val_top_10_acc: 0.9297 - lr: 9.8429e-04
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0009755282581475768.
# learning rate: 9.76e-04, weight decay: 4.88e-05
# Epoch 56/100
# 96/96 [==============================] - 90s 933ms/step - loss: 3.1679 - acc: 0.6367 - top_5_acc: 0.8473 - top_10_acc: 0.8931 - val_loss: 3.1218 - val_acc: 0.6154 - val_top_5_acc: 0.8793 - val_top_10_acc: 0.9272 - lr: 9.7553e-04
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.0009648882429441257.
# learning rate: 9.65e-04, weight decay: 4.82e-05
# Epoch 57/100
# 96/96 [==============================] - 90s 937ms/step - loss: 3.1267 - acc: 0.6538 - top_5_acc: 0.8571 - top_10_acc: 0.9000 - val_loss: 3.1208 - val_acc: 0.6146 - val_top_5_acc: 0.8757 - val_top_10_acc: 0.9270 - lr: 9.6489e-04
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0009524135262330098.
# learning rate: 9.52e-04, weight decay: 4.76e-05
# Epoch 58/100
# 96/96 [==============================] - 90s 937ms/step - loss: 3.0951 - acc: 0.6648 - top_5_acc: 0.8632 - top_10_acc: 0.9040 - val_loss: 3.1005 - val_acc: 0.6260 - val_top_5_acc: 0.8803 - val_top_10_acc: 0.9303 - lr: 9.5241e-04
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0009381533400219318.
# learning rate: 9.38e-04, weight decay: 4.69e-05
# Epoch 59/100
# 96/96 [==============================] - 90s 936ms/step - loss: 3.0860 - acc: 0.6665 - top_5_acc: 0.8651 - top_10_acc: 0.9052 - val_loss: 3.0501 - val_acc: 0.6508 - val_top_5_acc: 0.8922 - val_top_10_acc: 0.9371 - lr: 9.3815e-04
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0009221639627510075.
# learning rate: 9.22e-04, weight decay: 4.61e-05
# Epoch 60/100
# 96/96 [==============================] - 90s 937ms/step - loss: 3.0589 - acc: 0.6765 - top_5_acc: 0.8704 - top_10_acc: 0.9082 - val_loss: 3.0447 - val_acc: 0.6430 - val_top_5_acc: 0.8908 - val_top_10_acc: 0.9372 - lr: 9.2216e-04
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.0009045084971874737.
# learning rate: 9.05e-04, weight decay: 4.52e-05
# Epoch 61/100
# 96/96 [==============================] - 90s 936ms/step - loss: 3.0505 - acc: 0.6808 - top_5_acc: 0.8716 - top_10_acc: 0.9092 - val_loss: 3.0609 - val_acc: 0.6362 - val_top_5_acc: 0.8883 - val_top_10_acc: 0.9383 - lr: 9.0451e-04
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.0008852566213878947.
# learning rate: 8.85e-04, weight decay: 4.43e-05
# Epoch 62/100
# 96/96 [==============================] - 90s 937ms/step - loss: 3.0222 - acc: 0.6920 - top_5_acc: 0.8771 - top_10_acc: 0.9149 - val_loss: 3.0502 - val_acc: 0.6423 - val_top_5_acc: 0.8943 - val_top_10_acc: 0.9411 - lr: 8.8526e-04
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0008644843137107057.
# learning rate: 8.64e-04, weight decay: 4.32e-05
# Epoch 63/100
# 96/96 [==============================] - 90s 936ms/step - loss: 3.0034 - acc: 0.6987 - top_5_acc: 0.8811 - top_10_acc: 0.9173 - val_loss: 3.0368 - val_acc: 0.6479 - val_top_5_acc: 0.8920 - val_top_10_acc: 0.9389 - lr: 8.6448e-04
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.0008422735529643444.
# learning rate: 8.42e-04, weight decay: 4.21e-05
# Epoch 64/100
# 96/96 [==============================] - 90s 938ms/step - loss: 2.9893 - acc: 0.7054 - top_5_acc: 0.8826 - top_10_acc: 0.9174 - val_loss: 3.0692 - val_acc: 0.6367 - val_top_5_acc: 0.8870 - val_top_10_acc: 0.9320 - lr: 8.4227e-04
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0008187119948743449.
# learning rate: 8.19e-04, weight decay: 4.09e-05
# Epoch 65/100
# 96/96 [==============================] - 90s 936ms/step - loss: 2.9905 - acc: 0.7040 - top_5_acc: 0.8822 - top_10_acc: 0.9165 - val_loss: 3.0019 - val_acc: 0.6568 - val_top_5_acc: 0.9002 - val_top_10_acc: 0.9435 - lr: 8.1871e-04
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.0007938926261462366.
# learning rate: 7.94e-04, weight decay: 3.97e-05
# Epoch 66/100
# 96/96 [==============================] - 90s 937ms/step - loss: 2.9669 - acc: 0.7128 - top_5_acc: 0.8852 - top_10_acc: 0.9197 - val_loss: 3.0206 - val_acc: 0.6486 - val_top_5_acc: 0.8957 - val_top_10_acc: 0.9412 - lr: 7.9389e-04
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0007679133974894983.
# learning rate: 7.68e-04, weight decay: 3.84e-05
# Epoch 67/100
# 96/96 [==============================] - 90s 938ms/step - loss: 2.9445 - acc: 0.7211 - top_5_acc: 0.8903 - top_10_acc: 0.9232 - val_loss: 3.0427 - val_acc: 0.6492 - val_top_5_acc: 0.8930 - val_top_10_acc: 0.9374 - lr: 7.6791e-04
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.0007408768370508576.
# learning rate: 7.41e-04, weight decay: 3.70e-05
# Epoch 68/100
# 96/96 [==============================] - 90s 936ms/step - loss: 2.9433 - acc: 0.7208 - top_5_acc: 0.8909 - top_10_acc: 0.9239 - val_loss: 3.0159 - val_acc: 0.6533 - val_top_5_acc: 0.8945 - val_top_10_acc: 0.9387 - lr: 7.4088e-04
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.0007128896457825364.
# learning rate: 7.13e-04, weight decay: 3.56e-05
# Epoch 69/100
# 96/96 [==============================] - 90s 936ms/step - loss: 2.9340 - acc: 0.7227 - top_5_acc: 0.8925 - top_10_acc: 0.9248 - val_loss: 3.0039 - val_acc: 0.6577 - val_top_5_acc: 0.8961 - val_top_10_acc: 0.9406 - lr: 7.1289e-04
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.0006840622763423391.
# learning rate: 6.84e-04, weight decay: 3.42e-05
# Epoch 70/100
# 96/96 [==============================] - 90s 933ms/step - loss: 2.9138 - acc: 0.7323 - top_5_acc: 0.8963 - top_10_acc: 0.9267 - val_loss: 3.0001 - val_acc: 0.6543 - val_top_5_acc: 0.8920 - val_top_10_acc: 0.9369 - lr: 6.8406e-04
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.0006545084971874737.
# learning rate: 6.55e-04, weight decay: 3.27e-05
# Epoch 71/100
# 96/96 [==============================] - 89s 932ms/step - loss: 2.8982 - acc: 0.7395 - top_5_acc: 0.8998 - top_10_acc: 0.9294 - val_loss: 2.9960 - val_acc: 0.6588 - val_top_5_acc: 0.8967 - val_top_10_acc: 0.9427 - lr: 6.5451e-04
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0006243449435824276.
# learning rate: 6.24e-04, weight decay: 3.12e-05
# Epoch 72/100
# 96/96 [==============================] - 88s 922ms/step - loss: 2.8937 - acc: 0.7381 - top_5_acc: 0.9012 - top_10_acc: 0.9314 - val_loss: 3.0119 - val_acc: 0.6574 - val_top_5_acc: 0.8965 - val_top_10_acc: 0.9419 - lr: 6.2434e-04
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0005936906572928624.
# learning rate: 5.94e-04, weight decay: 2.97e-05
# Epoch 73/100
# 96/96 [==============================] - 89s 933ms/step - loss: 2.8848 - acc: 0.7428 - top_5_acc: 0.9012 - top_10_acc: 0.9311 - val_loss: 3.0029 - val_acc: 0.6631 - val_top_5_acc: 0.9001 - val_top_10_acc: 0.9418 - lr: 5.9369e-04
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.0005626666167821521.
# learning rate: 5.63e-04, weight decay: 2.81e-05
# Epoch 74/100
# 96/96 [==============================] - 90s 934ms/step - loss: 2.8711 - acc: 0.7481 - top_5_acc: 0.9041 - top_10_acc: 0.9333 - val_loss: 2.9963 - val_acc: 0.6601 - val_top_5_acc: 0.9027 - val_top_10_acc: 0.9442 - lr: 5.6267e-04
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.0005313952597646568.
# learning rate: 5.31e-04, weight decay: 2.66e-05
# Epoch 75/100
# 96/96 [==============================] - 89s 932ms/step - loss: 2.8675 - acc: 0.7502 - top_5_acc: 0.9041 - top_10_acc: 0.9331 - val_loss: 3.0114 - val_acc: 0.6590 - val_top_5_acc: 0.9011 - val_top_10_acc: 0.9417 - lr: 5.3140e-04
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.0005.
# learning rate: 5.00e-04, weight decay: 2.50e-05
# Epoch 76/100
# 96/96 [==============================] - 89s 931ms/step - loss: 2.8531 - acc: 0.7570 - top_5_acc: 0.9077 - top_10_acc: 0.9348 - val_loss: 2.9959 - val_acc: 0.6611 - val_top_5_acc: 0.9021 - val_top_10_acc: 0.9430 - lr: 5.0000e-04
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.0004686047402353433.
# learning rate: 4.69e-04, weight decay: 2.34e-05
# Epoch 77/100
# 96/96 [==============================] - 89s 932ms/step - loss: 2.8416 - acc: 0.7592 - top_5_acc: 0.9076 - top_10_acc: 0.9358 - val_loss: 2.9845 - val_acc: 0.6590 - val_top_5_acc: 0.9006 - val_top_10_acc: 0.9416 - lr: 4.6860e-04
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.00043733338321784784.
# learning rate: 4.37e-04, weight decay: 2.19e-05
# Epoch 78/100
# 96/96 [==============================] - 89s 932ms/step - loss: 2.8321 - acc: 0.7631 - top_5_acc: 0.9104 - top_10_acc: 0.9367 - val_loss: 3.0179 - val_acc: 0.6562 - val_top_5_acc: 0.8991 - val_top_10_acc: 0.9408 - lr: 4.3733e-04
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.0004063093427071376.
# learning rate: 4.06e-04, weight decay: 2.03e-05
# Epoch 79/100
# 96/96 [==============================] - 89s 932ms/step - loss: 2.8194 - acc: 0.7683 - top_5_acc: 0.9117 - top_10_acc: 0.9385 - val_loss: 2.9826 - val_acc: 0.6652 - val_top_5_acc: 0.9001 - val_top_10_acc: 0.9425 - lr: 4.0631e-04
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.0003756550564175727.
# learning rate: 3.76e-04, weight decay: 1.88e-05
# Epoch 80/100
# 96/96 [==============================] - 88s 922ms/step - loss: 2.8132 - acc: 0.7699 - top_5_acc: 0.9139 - top_10_acc: 0.9389 - val_loss: 2.9950 - val_acc: 0.6604 - val_top_5_acc: 0.9034 - val_top_10_acc: 0.9435 - lr: 3.7566e-04
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.00034549150281252633.
# learning rate: 3.45e-04, weight decay: 1.73e-05
# Epoch 81/100
# 96/96 [==============================] - 89s 933ms/step - loss: 2.8079 - acc: 0.7724 - top_5_acc: 0.9139 - top_10_acc: 0.9395 - val_loss: 2.9790 - val_acc: 0.6648 - val_top_5_acc: 0.9018 - val_top_10_acc: 0.9430 - lr: 3.4549e-04
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.00031593772365766105.
# learning rate: 3.16e-04, weight decay: 1.58e-05
# Epoch 82/100
# 96/96 [==============================] - 89s 933ms/step - loss: 2.7978 - acc: 0.7759 - top_5_acc: 0.9162 - top_10_acc: 0.9409 - val_loss: 2.9723 - val_acc: 0.6668 - val_top_5_acc: 0.9078 - val_top_10_acc: 0.9452 - lr: 3.1594e-04
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.00028711035421746366.
# learning rate: 2.87e-04, weight decay: 1.44e-05
# Epoch 83/100
# 96/96 [==============================] - 89s 923ms/step - loss: 2.7921 - acc: 0.7774 - top_5_acc: 0.9175 - top_10_acc: 0.9419 - val_loss: 2.9627 - val_acc: 0.6694 - val_top_5_acc: 0.9079 - val_top_10_acc: 0.9467 - lr: 2.8711e-04
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0002591231629491423.
# learning rate: 2.59e-04, weight decay: 1.30e-05
# Epoch 84/100
# 96/96 [==============================] - 89s 932ms/step - loss: 2.7821 - acc: 0.7826 - top_5_acc: 0.9193 - top_10_acc: 0.9433 - val_loss: 2.9785 - val_acc: 0.6692 - val_top_5_acc: 0.9055 - val_top_10_acc: 0.9467 - lr: 2.5912e-04
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.00023208660251050156.
# learning rate: 2.32e-04, weight decay: 1.16e-05
# Epoch 85/100
# 96/96 [==============================] - 89s 923ms/step - loss: 2.7795 - acc: 0.7832 - top_5_acc: 0.9186 - top_10_acc: 0.9429 - val_loss: 3.0007 - val_acc: 0.6591 - val_top_5_acc: 0.9008 - val_top_10_acc: 0.9419 - lr: 2.3209e-04
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.00020610737385376348.
# learning rate: 2.06e-04, weight decay: 1.03e-05
# Epoch 86/100
# 96/96 [==============================] - 89s 923ms/step - loss: 2.7692 - acc: 0.7873 - top_5_acc: 0.9209 - top_10_acc: 0.9433 - val_loss: 2.9805 - val_acc: 0.6698 - val_top_5_acc: 0.9062 - val_top_10_acc: 0.9466 - lr: 2.0611e-04
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.00018128800512565513.
# learning rate: 1.81e-04, weight decay: 9.06e-06
# Epoch 87/100
# 96/96 [==============================] - 89s 923ms/step - loss: 2.7602 - acc: 0.7910 - top_5_acc: 0.9206 - top_10_acc: 0.9448 - val_loss: 2.9788 - val_acc: 0.6662 - val_top_5_acc: 0.9049 - val_top_10_acc: 0.9446 - lr: 1.8129e-04
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.00015772644703565563.
# learning rate: 1.58e-04, weight decay: 7.89e-06
# Epoch 88/100
# 96/96 [==============================] - 90s 934ms/step - loss: 2.7648 - acc: 0.7870 - top_5_acc: 0.9209 - top_10_acc: 0.9442 - val_loss: 2.9724 - val_acc: 0.6696 - val_top_5_acc: 0.9063 - val_top_10_acc: 0.9469 - lr: 1.5773e-04
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.00013551568628929433.
# learning rate: 1.36e-04, weight decay: 6.78e-06
# Epoch 89/100
# 96/96 [==============================] - 89s 932ms/step - loss: 2.7519 - acc: 0.7944 - top_5_acc: 0.9224 - top_10_acc: 0.9458 - val_loss: 2.9689 - val_acc: 0.6694 - val_top_5_acc: 0.9062 - val_top_10_acc: 0.9468 - lr: 1.3552e-04
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.00011474337861210544.
# learning rate: 1.15e-04, weight decay: 5.74e-06
# Epoch 90/100
# 96/96 [==============================] - 89s 931ms/step - loss: 2.7558 - acc: 0.7914 - top_5_acc: 0.9223 - top_10_acc: 0.9458 - val_loss: 2.9826 - val_acc: 0.6673 - val_top_5_acc: 0.9035 - val_top_10_acc: 0.9439 - lr: 1.1474e-04
#
# Epoch 91: LearningRateScheduler setting learning rate to 9.549150281252633e-05.
# learning rate: 9.55e-05, weight decay: 4.77e-06
# Epoch 91/100
# 96/96 [==============================] - 89s 922ms/step - loss: 2.7460 - acc: 0.7966 - top_5_acc: 0.9241 - top_10_acc: 0.9461 - val_loss: 2.9586 - val_acc: 0.6735 - val_top_5_acc: 0.9074 - val_top_10_acc: 0.9465 - lr: 9.5492e-05
#
# Epoch 92: LearningRateScheduler setting learning rate to 7.783603724899258e-05.
# learning rate: 7.78e-05, weight decay: 3.89e-06
# Epoch 92/100
# 96/96 [==============================] - 90s 933ms/step - loss: 2.7460 - acc: 0.7956 - top_5_acc: 0.9240 - top_10_acc: 0.9474 - val_loss: 2.9638 - val_acc: 0.6760 - val_top_5_acc: 0.9084 - val_top_10_acc: 0.9479 - lr: 7.7836e-05
#
# Epoch 93: LearningRateScheduler setting learning rate to 6.184665997806832e-05.
# learning rate: 6.18e-05, weight decay: 3.09e-06
# Epoch 93/100
# 96/96 [==============================] - 90s 933ms/step - loss: 2.7391 - acc: 0.8000 - top_5_acc: 0.9258 - top_10_acc: 0.9469 - val_loss: 2.9511 - val_acc: 0.6758 - val_top_5_acc: 0.9094 - val_top_10_acc: 0.9479 - lr: 6.1847e-05
#
# Epoch 94: LearningRateScheduler setting learning rate to 4.758647376699032e-05.
# learning rate: 4.76e-05, weight decay: 2.38e-06
# Epoch 94/100
# 96/96 [==============================] - 89s 932ms/step - loss: 2.7325 - acc: 0.8008 - top_5_acc: 0.9262 - top_10_acc: 0.9487 - val_loss: 2.9698 - val_acc: 0.6730 - val_top_5_acc: 0.9082 - val_top_10_acc: 0.9454 - lr: 4.7586e-05
#
# Epoch 95: LearningRateScheduler setting learning rate to 3.5111757055874326e-05.
# learning rate: 3.51e-05, weight decay: 1.76e-06
# Epoch 95/100
# 96/96 [==============================] - 90s 934ms/step - loss: 2.7271 - acc: 0.8018 - top_5_acc: 0.9277 - top_10_acc: 0.9489 - val_loss: 2.9674 - val_acc: 0.6737 - val_top_5_acc: 0.9077 - val_top_10_acc: 0.9467 - lr: 3.5112e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 2.4471741852423235e-05.
# learning rate: 2.45e-05, weight decay: 1.22e-06
# Epoch 96/100
# 96/96 [==============================] - 89s 933ms/step - loss: 2.7276 - acc: 0.8029 - top_5_acc: 0.9268 - top_10_acc: 0.9489 - val_loss: 2.9682 - val_acc: 0.6733 - val_top_5_acc: 0.9071 - val_top_10_acc: 0.9461 - lr: 2.4472e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 1.5708419435684463e-05.
# learning rate: 1.57e-05, weight decay: 7.85e-07
# Epoch 97/100
# 96/96 [==============================] - 90s 937ms/step - loss: 2.7287 - acc: 0.8037 - top_5_acc: 0.9262 - top_10_acc: 0.9483 - val_loss: 2.9590 - val_acc: 0.6747 - val_top_5_acc: 0.9076 - val_top_10_acc: 0.9463 - lr: 1.5708e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 8.856374635655695e-06.
# learning rate: 8.86e-06, weight decay: 4.43e-07
# Epoch 98/100
# 96/96 [==============================] - 90s 936ms/step - loss: 2.7250 - acc: 0.8057 - top_5_acc: 0.9264 - top_10_acc: 0.9489 - val_loss: 2.9612 - val_acc: 0.6750 - val_top_5_acc: 0.9069 - val_top_10_acc: 0.9467 - lr: 8.8564e-06
#
# Epoch 99: LearningRateScheduler setting learning rate to 3.942649342761117e-06.
# learning rate: 3.94e-06, weight decay: 1.97e-07
# Epoch 99/100
# 96/96 [==============================] - 90s 938ms/step - loss: 2.7320 - acc: 0.8022 - top_5_acc: 0.9245 - top_10_acc: 0.9465 - val_loss: 2.9601 - val_acc: 0.6741 - val_top_5_acc: 0.9073 - val_top_10_acc: 0.9465 - lr: 3.9426e-06
#
# Epoch 100: LearningRateScheduler setting learning rate to 9.866357858642206e-07.
# learning rate: 9.87e-07, weight decay: 4.93e-08
# Epoch 100/100
# 96/96 [==============================] - 90s 937ms/step - loss: 2.7291 - acc: 0.8026 - top_5_acc: 0.9265 - top_10_acc: 0.9482 - val_loss: 2.9616 - val_acc: 0.6732 - val_top_5_acc: 0.9068 - val_top_10_acc: 0.9464 - lr: 9.8664e-07

# %%
def plot_history_metric(metric, f_best=np.argmax, ylim=None, yscale=None, yticks=None):
    plt.figure(figsize=(20, 10))

    values = lstm_history.history[metric]
    N_EPOCHS = len(values)
    val = 'val' in ''.join(lstm_history.history.keys())
    # Epoch Ticks
    if N_EPOCHS <= 20:
        x = np.arange(1, N_EPOCHS + 1)
    else:
        x = [1, 5] + [10 + 5 * idx for idx in range((N_EPOCHS - 10) // 5 + 1)]

    x_ticks = np.arange(1, N_EPOCHS+1)

    # Validation
    if val:
        val_values = lstm_history.history[f'val_{metric}']
        val_argmin = f_best(val_values)
        plt.plot(x_ticks, val_values, label=f'val')

    # summarize history for accuracy
    plt.plot(x_ticks, values, label=f'train')
    argmin = f_best(values)
    plt.scatter(argmin + 1, values[argmin], color='red', s=75, marker='o', label=f'train_best')
    if val:
        plt.scatter(val_argmin + 1, val_values[val_argmin], color='purple', s=75, marker='o', label=f'val_best')

    plt.title(f'Model {metric}', fontsize=24, pad=10)
    plt.ylabel(metric, fontsize=20, labelpad=10)

    if ylim:
        plt.ylim(ylim)

    if yscale is not None:
        plt.yscale(yscale)

    if yticks is not None:
        plt.yticks(yticks, fontsize=16)

    plt.xlabel('epoch', fontsize=20, labelpad=10)
    plt.tick_params(axis='x', labelsize=8)
    plt.xticks(x, fontsize=16) # set tick step to 1 and let x axis start at 1
    plt.yticks(fontsize=16)

    plt.legend(prop={'size': 10})
    plt.grid()
    plt.show()

# %%
plot_history_metric('acc', ylim=[0,1], yticks=np.arange(0.0, 1.1, 0.1))

# %%
plot_history_metric('top_5_acc', ylim=[0,1], yticks=np.arange(0.0, 1.1, 0.1))

# %%
plot_history_metric('top_10_acc', ylim=[0,1], yticks=np.arange(0.0, 1.1, 0.1))

# %%
plot_history_metric('loss', f_best=np.argmin)
